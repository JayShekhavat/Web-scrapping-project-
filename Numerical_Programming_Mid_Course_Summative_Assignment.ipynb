# %% [markdown]
# <a href="https://colab.research.google.com/github/JayShekhavat/Web-scrapping-project-/blob/main/Numerical_Programming_Mid_Course_Summative_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement: Navigating the Data Science Job Landscape**
#
# 🚀 Unleash your creativity in crafting a solution that taps into the heartbeat of the data science job market! Envision an ingenious project that seamlessly wields cutting-edge web scraping techniques and illuminating data analysis.
#
# 🔍 Your mission? To engineer a tool that effortlessly gathers job listings from a multitude of online sources, extracting pivotal nuggets such as job descriptions, qualifications, locations, and salaries.
#
# 🧩 However, the true puzzle lies in deciphering this trove of data. Can your solution discern patterns that spotlight the most coveted skills? Are there threads connecting job types to compensation packages? How might it predict shifts in industry demand?
#
# 🎯 The core objectives of this challenge are as follows:
#
# 1. Web Scraping Mastery: Forge an adaptable and potent web scraping mechanism. Your creation should adeptly harvest data science job postings from a diverse array of online platforms. Be ready to navigate evolving website structures and process hefty data loads.
#
# 2. Data Symphony: Skillfully distill vital insights from the harvested job listings. Extract and cleanse critical information like job titles, company names, descriptions, qualifications, salaries, locations, and deadlines. Think data refinement and organization.
#
# 3. Market Wizardry: Conjure up analytical tools that conjure meaningful revelations from the gathered data. Dive into the abyss of job demand trends, geographic distribution, salary variations tied to experience and location, favored qualifications, and emerging skill demands.
#
# 4. Visual Magic: Weave a tapestry of visualization magic. Design captivating charts, graphs, and visual representations that paint a crystal-clear picture of the analyzed data. Make these visuals the compass that guides users through job market intricacies.
#
# 🌐 While the web scraping universe is yours to explore, consider these platforms as potential stomping grounds:
#
# * LinkedIn Jobs
# * Indeed
# * Naukri
# * Glassdoor
# * AngelList
#
# 🎈 Your solution should not only decode the data science job realm but also empower professionals, job seekers, and recruiters to harness the dynamic shifts of the industry. The path is open, the challenge beckons – are you ready to embark on this exciting journey?

# %% [markdown]
# ##**Modulary of code**

# %% [markdown]
# #**Scrapping the websites**

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Install the Request and beautifulSoup libraries**

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
import requests
print(requests.__version__)
# Out:
# 2.31.0

# %%
! pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %% [markdown]
# #**Import libraries**

# %%
# Import the necessary libraries
import requests
from bs4 import BeautifulSoup
import re
import csv

# %% [markdown]
# #**Scrapping Movies Data**

# %%
# Define the URL of the webpage to be scraped
url = 'https://www.justwatch.com/in/movies?release_year_from=2000'

page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
#   <meta content="302" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/>
#   <meta content="yes" data-vue-meta="ssr" name="mobile-web-app-capable"/>
#   <meta content="yes" data-vue-meta="ssr" name="apple-mobile-web-app-capable"/>
#   <meta content="#182531" data-vue-meta="ssr" name="theme-color"/>
#   <meta content="4eBTNBm4L6RaWdF8V51EHZajskAMgXYAg81iRXJqumQ" data-vue-meta="ssr" name="google-site-verification"/>
#   <meta content="d61y4roe8t5xwbb0gfu6gwe8j8iq3i" data-vue-meta="ssr" name="facebook-domain-verification"/>
#   <meta content="dmorpwc4h544ct6mv" data-vue-meta="ssr" name="dailymotion-domain-verification"/>
#   <meta content="Watch movies online" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/>
#   <meta content="movies, watch online, streaming, rental, download" data-vue-meta="ssr" name="keywords"/>
#   <meta content="Where to watch movies online? Find with JustWatch all the movies you can watch online on Netflix, iflix, Hooq and 4 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="description" data-vue-meta="ssr" name="description"/>
#   <meta content="Where to watch movies online? Find with JustWatch all the movies you can watch online on Netflix, iflix, Hooq and 4 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="og:description" data-vue-meta="ssr" property="og:description"/>
#   <meta content="noindex, follow" data-vmid="robots" data-vue-meta="ssr" name="robots"/>
#   <title>
#    Watch movies online
#   </title>
#   <link data-vue-meta="ssr" href="https://app.usercentrics.eu" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://graphql.usercentrics.eu" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://api.usercentrics.eu" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://consents.usercentrics.eu" rel="dns-prefetch"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-700.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-900.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/anton.woff" rel="preload" type="font/woff2"/>
#   <link data-vue-meta="ssr" href="/appassets/favicon.ico" rel="icon"/>
#   <link crossorigin="use-credentials" data-vue-meta="ssr" href="https://images.justwatch.com" rel="preconnect"/>
#   <link data-vue-meta="ssr" href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://ib.adnxs.com" rel="dns-prefetch"/>
#   <link data-vmid="canonical" data-vue-meta="ssr" href="https://www.justwatch.com/in/movies" rel="canonical"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ad/pellicules" hreflang="ca-AD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ae/movies" hreflang="ar-AE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ag/movies" hreflang="en-AG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/al/filmat" hreflang="sq-AL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ao/filmes" hreflang="pt-AO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ar/peliculas" hreflang="es-AR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/at/Filme" hreflang="de-AT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/au/movies" hreflang="en-AU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/az/filmlər" hreflang="az-AZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ba/filmovi" hreflang="bs-BA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bb/movies" hreflang="en-BB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/be/films" hreflang="fr-BE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bf/films" hreflang="fr-BF" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bg/филми" hreflang="bg-BG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bh/movies" hreflang="ar-BH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bm/movies" hreflang="en-BM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bo/peliculas" hreflang="es-BO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/br/filmes" hreflang="pt-BR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bs/movies" hreflang="en-BS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/by/фільмы" hreflang="be-BY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bz/movies" hreflang="en-BZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ca/movies" hreflang="en-CA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cd/films" hreflang="fr-CD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ch/Filme" hreflang="de-CH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ci/films" hreflang="fr-CI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cl/peliculas" hreflang="es-CL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cm/movies" hreflang="en-CM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/co/peliculas" hreflang="es-CO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cr/peliculas" hreflang="es-CR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cu/peliculas" hreflang="es-CU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cv/filmes" hreflang="pt-CV" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cy/ταινίες" hreflang="el-CY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cz/filmy" hreflang="cs-CZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/de/Filme" hreflang="de-DE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dk/movies" hreflang="en-DK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/do/peliculas" hreflang="es-DO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dz/movies" hreflang="ar-DZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ec/peliculas" hreflang="es-EC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/eg/movies" hreflang="ar-EG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/es/peliculas" hreflang="es-ES" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fi/elokuvat" hreflang="fi-FI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fj/movies" hreflang="en-FJ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fr/films" hreflang="fr-FR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uk/movies" hreflang="en-GB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gf/films" hreflang="fr-GF" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gg/movies" hreflang="en-GG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gh/movies" hreflang="en-GH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gi/movies" hreflang="en-GI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gq/peliculas" hreflang="es-GQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gr/ταινίες" hreflang="el-GR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gt/peliculas" hreflang="es-GT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gy/movies" hreflang="en-GY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hk/電影" hreflang="zh-HK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hn/peliculas" hreflang="es-HN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hr/filmovi" hreflang="hr-HR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hu/filmek" hreflang="hu-HU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ie/movies" hreflang="en-IE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/il/movies" hreflang="he-IL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/in/movies" hreflang="en-IN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/iq/movies" hreflang="ar-IQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/is/kvikmyndir" hreflang="is-IS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/it/film" hreflang="it-IT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jm/movies" hreflang="en-JM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jo/movies" hreflang="ar-JO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jp/映画" hreflang="ja-JP" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ke/movies" hreflang="en-KE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kr/영화" hreflang="ko-KR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kw/movies" hreflang="ar-KW" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lb/movies" hreflang="ar-LB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lc/movies" hreflang="en-LC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/li/Filme" hreflang="de-LI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lu/films" hreflang="fr-LU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ly/movies" hreflang="ar-LY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ma/movies" hreflang="ar-MA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mc/films" hreflang="fr-MC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/md/filme" hreflang="ro-MD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/me/filmovi" hreflang="sr-ME" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mg/films" hreflang="fr-MG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mk/филмови" hreflang="mk-MK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ml/films" hreflang="fr-ML" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mt/films" hreflang="mt-MT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mu/films" hreflang="fr-MU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mw/movies" hreflang="en-MW" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mx/peliculas" hreflang="es-MX" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/my/movies" hreflang="en-MY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mz/filmes" hreflang="pt-MZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ne/films" hreflang="fr-NE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ng/movies" hreflang="en-NG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ni/peliculas" hreflang="es-NI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nl/movies" hreflang="en-NL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/no/movies" hreflang="en-NO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nz/movies" hreflang="en-NZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/om/movies" hreflang="ar-OM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pa/peliculas" hreflang="es-PA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pe/peliculas" hreflang="es-PE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pf/films" hreflang="fr-PF" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pg/movies" hreflang="en-PG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ph/movies" hreflang="en-PH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pk/movies" hreflang="ur-PK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pl/filmy" hreflang="pl-PL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ps/movies" hreflang="ar-PS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pt/filmes" hreflang="pt-PT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/py/peliculas" hreflang="es-PY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/qa/movies" hreflang="ar-QA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ro/filme" hreflang="ro-RO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/rs/filmovi" hreflang="sr-RS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ru/фильмы" hreflang="ru-RU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sa/movies" hreflang="ar-SA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sc/films" hreflang="fr-SC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/se/filmer" hreflang="sv-SE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sg/movies" hreflang="en-SG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/si/filmi" hreflang="sl-SI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sk/filmy" hreflang="sk-SK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sm/film" hreflang="it-SM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sn/films" hreflang="fr-SN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sv/peliculas" hreflang="es-SV" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tc/movies" hreflang="en-TC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/td/movies" hreflang="ar-TD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tn/movies" hreflang="ar-TN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tr/filmler" hreflang="tr-TR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tt/movies" hreflang="en-TT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tz/filamu" hreflang="sw-TZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ua/фільми" hreflang="uk-UA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ug/movies" hreflang="en-UG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/us/movies" hreflang="en-US" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uy/peliculas" hreflang="es-UY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/va/film" hreflang="it-VA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ve/peliculas" hreflang="es-VE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/xk/filmat" hreflang="sq-XK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ye/movies" hreflang="ar-YE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/za/movies" hreflang="en-ZA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/zm/movies" hreflang="en-ZM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/zw/movies" hreflang="en-ZW" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ee/filmid" hreflang="et-EE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lv/filmas" hreflang="lv-LV" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lt/filmai" hreflang="lt-LT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/id/movies" hreflang="en-ID" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/th/movies" hreflang="en-TH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tw/電影" hreflang="zh-TW" rel="alternate"/>
#   <base href="/" target="_self"/>
#   <link as="image" href="/appassets/img/logo/JustWatch-logo-large.webp" imagesrcset="/appassets/img/logo/JustWatch-logo-large.webp 1px" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/4233119/s100/voot.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/4233119/s100/voot.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/307624479/s166/animal-2022.webp" imagesrcset="https://www.justwatch.com/images/poster/307624479/s166/animal-2022.webp 1px, https://www.justwatch.com/images/poster/307624479/s166/animal-2022.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/309089240/s166/12th-fail.webp" imagesrcset="https://www.justwatch.com/images/poster/309089240/s166/12th-fail.webp 1px, https://www.justwatch.com/images/poster/309089240/s166/12th-fail.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/310502799/s166/salaar.webp" imagesrcset="https://www.justwatch.com/images/poster/310502799/s166/salaar.webp 1px, https://www.justwatch.com/images/poster/310502799/s166/salaar.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/311483271/s166/sam-bahadur.webp" imagesrcset="https://www.justwatch.com/images/poster/311483271/s166/sam-bahadur.webp 1px, https://www.justwatch.com/images/poster/311483271/s166/sam-bahadur.webp" importance="high" rel="preload"/>
#   <style data-vue-ssr-id="16dee5de:0 16dee5de:1 374c0f88:0 4d630dd0:0 290963e8:0 30404f7e:0 2c4532b4:0 4dfbcd23:0 f084ba36:0 ea4d06ee:0 6dcc8ee6:0 244ddff4:0 69fd216c:0 08ddf3ea:0 10155196:0 0205dd46:0 26e8eb5f:0 71268dee:0 04f1c005:0 6de04a75:0 6240279c:0 72101108:0 40c85688:0 6d26d0c3:0 754b4d6b:0 d9ba2922:0 588ea6ac:0 c5a4a028:0 03e9b512:0 15d0a34a:0 44770f63:0 3cf28c3e:0 0de9810f:0 72740b88:0 493a7b4c:0">
#    html.ios{--ion-default-font:-apple-system,BlinkMacSystemFont,"Helvetica Neue","Roboto",sans-serif}html.md{--ion-default-font:"Roboto","Helvetica Neue",sans-serif}html{--ion-font-family:var(--ion-default-font)}body{background:var(--ion-background-color)}body.backdrop-no-scroll{overflow:hidden}html.ios ion-modal.modal-card .ion-page>ion-header>ion-toolbar:first-of-type{padding-top:0}html.ios ion-modal .ion-page{border-radius:inherit}.ion-color-primary{--ion-color-base:var(--ion-color-primary,#3880ff)!important;--ion-color-base-rgb:var(--ion-color-primary-rgb,56,128,255)!important;--ion-color-contrast:var(--ion-color-primary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-primary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-primary-shade,#3171e0)!important;--ion-color-tint:var(--ion-color-primary-tint,#4c8dff)!important}.ion-color-secondary{--ion-color-base:var(--ion-color-secondary,#3dc2ff)!important;--ion-color-base-rgb:var(--ion-color-secondary-rgb,61,194,255)!important;--ion-color-contrast:var(--ion-color-secondary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-secondary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-secondary-shade,#36abe0)!important;--ion-color-tint:var(--ion-color-secondary-tint,#50c8ff)!important}.ion-color-tertiary{--ion-color-base:var(--ion-color-tertiary,#5260ff)!important;--ion-color-base-rgb:var(--ion-color-tertiary-rgb,82,96,255)!important;--ion-color-contrast:var(--ion-color-tertiary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-tertiary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-tertiary-shade,#4854e0)!important;--ion-color-tint:var(--ion-color-tertiary-tint,#6370ff)!important}.ion-color-success{--ion-color-base:var(--ion-color-success,#2dd36f)!important;--ion-color-base-rgb:var(--ion-color-success-rgb,45,211,111)!important;--ion-color-contrast:var(--ion-color-success-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-success-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-success-shade,#28ba62)!important;--ion-color-tint:var(--ion-color-success-tint,#42d77d)!important}.ion-color-warning{--ion-color-base:var(--ion-color-warning,#ffc409)!important;--ion-color-base-rgb:var(--ion-color-warning-rgb,255,196,9)!important;--ion-color-contrast:var(--ion-color-warning-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-warning-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-warning-shade,#e0ac08)!important;--ion-color-tint:var(--ion-color-warning-tint,#ffca22)!important}.ion-color-danger{--ion-color-base:var(--ion-color-danger,#eb445a)!important;--ion-color-base-rgb:var(--ion-color-danger-rgb,235,68,90)!important;--ion-color-contrast:var(--ion-color-danger-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-danger-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-danger-shade,#cf3c4f)!important;--ion-color-tint:var(--ion-color-danger-tint,#ed576b)!important}.ion-color-light{--ion-color-base:var(--ion-color-light,#f4f5f8)!important;--ion-color-base-rgb:var(--ion-color-light-rgb,244,245,248)!important;--ion-color-contrast:var(--ion-color-light-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-light-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-light-shade,#d7d8da)!important;--ion-color-tint:var(--ion-color-light-tint,#f5f6f9)!important}.ion-color-medium{--ion-color-base:var(--ion-color-medium,#92949c)!important;--ion-color-base-rgb:var(--ion-color-medium-rgb,146,148,156)!important;--ion-color-contrast:var(--ion-color-medium-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-medium-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-medium-shade,#808289)!important;--ion-color-tint:var(--ion-color-medium-tint,#9d9fa6)!important}.ion-color-dark{--ion-color-base:var(--ion-color-dark,#222428)!important;--ion-color-b ...
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:transparent!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:" (" attr(href) ")"}abbr[title]:after{content:" (" attr(title) ")"}a[href^="#"]:after,a[href^="javascript:"]:after{content:""}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn>.caret,.dropup>.btn>.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{font-family:Lato,Lato-fallback,Arial,sans-serif;font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#428bca}a,a:focus,a:hover{text-decoration:none}a:focus,a:hover{color:#2a6496}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container:after,.container:before{display:table;content:" "}.container:after{clear:both}@media(min-width:768px){.container{width:750px}}@media(min-width:992px){.container{width:970px}}@media(min-width:1200px){.container{width:1170px}}.container-fluid{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before{display:table;content:" "}.container-fluid:after{clear:both}.row{margin-right:-15px;margin-left:-15px}.row:after,.row:before{display:table;content:" "}.row:after{clear:both}.row-no-gutters{margin-right:0;margin-left:0}.row-no-gutters [class*=col-]{padding-right:0;padding-left:0}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{position:relative;min-height:1px;padding-right:15px;padding-left:15px}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{width:50%}.col-xs-7{width:58.3333333333%}.col-xs-8{width:66.6666666667%}.col-xs-9{width:75%}.col-xs-10{width:83.3333333333%}.col-xs-11{width:91.6666666667%}.col-xs-12{width:100%}.col-xs-pull-0{right:auto}.col-xs-pull-1{right:8.3333333333%}.col-xs-pull-2{right:16.6666666667%}.col-xs-pull-3{right:25%}.col-xs-pull-4{right:33.3333333333%}.col-xs-pull-5{right ...
# :host,:root{--fa-font-solid:normal 900 1em/1 "Font Awesome 6 Solid";--fa-font-regular:normal 400 1em/1 "Font Awesome 6 Regular";--fa-font-light:normal 300 1em/1 "Font Awesome 6 Light";--fa-font-thin:normal 100 1em/1 "Font Awesome 6 Thin";--fa-font-duotone:normal 900 1em/1 "Font Awesome 6 Duotone";--fa-font-sharp-solid:normal 900 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-regular:normal 400 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-light:normal 300 1em/1 "Font Awesome 6 Sharp";--fa-font-brands:normal 400 1em/1 "Font Awesome 6 Brands"}svg:not(:host).svg-inline--fa,svg:not(:root).svg-inline--fa{overflow:visible;box-sizing:content-box}.svg-inline--fa{display:var(--fa-display,inline-block);height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-2xs{vertical-align:.1em}.svg-inline--fa.fa-xs{vertical-align:0}.svg-inline--fa.fa-sm{vertical-align:-.07143em}.svg-inline--fa.fa-lg{vertical-align:-.2em}.svg-inline--fa.fa-xl{vertical-align:-.25em}.svg-inline--fa.fa-2xl{vertical-align:-.3125em}.svg-inline--fa.fa-pull-left{margin-right:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-pull-right{margin-left:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-li{width:var(--fa-li-width,2em);top:.25em}.svg-inline--fa.fa-fw{width:var(--fa-fw-width,1.25em)}.fa-layers svg.svg-inline--fa{bottom:0;left:0;margin:auto;position:absolute;right:0;top:0}.fa-layers-counter,.fa-layers-text{display:inline-block;position:absolute;text-align:center}.fa-layers{display:inline-block;height:1em;position:relative;text-align:center;vertical-align:-.125em;width:1em}.fa-layers svg.svg-inline--fa{transform-origin:center center}.fa-layers-text{left:50%;top:50%;transform:translate(-50%,-50%);transform-origin:center center}.fa-layers-counter{background-color:var(--fa-counter-background-color,#ff253a);border-radius:var(--fa-counter-border-radius,1em);box-sizing:border-box;color:var(--fa-inverse,#fff);line-height:var(--fa-counter-line-height,1);max-width:var(--fa-counter-max-width,5em);min-width:var(--fa-counter-min-width,1.5em);overflow:hidden;padding:var(--fa-counter-padding,.25em .5em);right:var(--fa-right,0);text-overflow:ellipsis;top:var(--fa-top,0);transform:scale(var(--fa-counter-scale,.25));transform-origin:top right}.fa-layers-bottom-right{bottom:var(--fa-bottom,0);right:var(--fa-right,0);top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom right}.fa-layers-bottom-left{bottom:var(--fa-bottom,0);left:var(--fa-left,0);right:auto;top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom left}.fa-layers-top-right{top:var(--fa-top,0);right:var(--fa-right,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top right}.fa-layers-top-left{left:var(--fa-left,0);right:auto;top:var(--fa-top,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top left}.fa-1x{font-size:1em}.fa-2x{font-size:2em}.fa-3x{font-size:3em}.fa-4x{font-size:4em}.fa-5x{font-size:5em}.fa-6x{font-size:6em}.fa-7x{font-size:7em}.fa-8x{font-size:8em}.fa-9x{font-size:9em}.fa-10x{font-size:10em}.fa-2xs{font-size:.625em;line-height:.1em;vertical-align:.225em}.fa-xs{font-size:.75em;line-height:.08333em;vertical-align:.125em}.fa-sm{font-size:.875em;line-height:.07143em;vertical-align:.05357em}.fa-lg{font-size:1.25em;line-height:.05em;vertical-align:-.075em}.fa-xl{font-size:1.5em;line-height:.04167em;vertical-align:-.125em}.fa-2xl{font-size:2em;line-height:.03125em;vertical-align:-.1875em}.fa-fw{text-align:center;width:1.25em}.fa-ul{list-style-type:none;margin-left:var(--fa-li-margin,2.5em);padding-left:0}.fa-ul>li{position:relative}.fa-li{left:calc(var(--fa-li-width, 2em)*-1);position:absolute;text-align:center;width:var(--fa-li-width,2em);line-height:inherit}.fa-border{border-radius:var(--fa-border-radius,.1em);border:var(--fa-border-width,.08em) var(--fa-border-style,solid) var(--fa-border-color,#eee);padding:var(--fa-border-padding,.2em .25em .15em)}.fa-pull-left{float:left;margin-right:var(--fa-pull-margin,.3em)}.fa ...
# .vue-recycle-scroller{position:relative}.vue-recycle-scroller.direction-vertical:not(.page-mode){overflow-y:auto}.vue-recycle-scroller.direction-horizontal:not(.page-mode){overflow-x:auto}.vue-recycle-scroller.direction-horizontal{display:-webkit-box;display:-ms-flexbox;display:flex}.vue-recycle-scroller__slot{-webkit-box-flex:1;-ms-flex:auto 0 0px;flex:auto 0 0}.vue-recycle-scroller__item-wrapper{-webkit-box-flex:1;-ms-flex:1;flex:1;-webkit-box-sizing:border-box;box-sizing:border-box;overflow:hidden;position:relative}.vue-recycle-scroller.ready .vue-recycle-scroller__item-view{position:absolute;top:0;left:0;will-change:transform}.vue-recycle-scroller.direction-vertical .vue-recycle-scroller__item-wrapper{width:100%}.vue-recycle-scroller.direction-horizontal .vue-recycle-scroller__item-wrapper{height:100%}.vue-recycle-scroller.ready.direction-vertical .vue-recycle-scroller__item-view{width:100%}.vue-recycle-scroller.ready.direction-horizontal .vue-recycle-scroller__item-view{height:100%}.resize-observer[data-v-b329ee4c]{border:none;background-color:transparent;opacity:0}.resize-observer[data-v-b329ee4c],.resize-observer[data-v-b329ee4c] object{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;pointer-events:none;display:block;overflow:hidden}
# body{overflow-x:hidden}ion-menu ion-content ion-toolbar,ion-popover ion-toolbar{--background:transparent!important}#app{position:relative;z-index:0}
# .navbar__button__link__item{text-transform:capitalize}.search-overlay{position:fixed;display:block;width:100vw;height:100vh;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);cursor:pointer}.navbar{position:-webkit-sticky;position:sticky;display:flex;background:#060d17;height:56px;width:100%;top:0;margin:0 auto;z-index:100}@media(max-width:1050px){.navbar{max-height:105px}}.navbar__wrapper{display:flex;justify-content:flex-end;width:100%;align-items:center;overflow:visible}@media(max-width:1050px){.navbar__wrapper{justify-content:center}}.navbar.navbar-hide{display:none!important}.navbar.landing-page{background:transparent}@media(min-width:1050px){.navbar.landing-page{height:86px;padding-top:15px;margin-bottom:-86px}.navbar.landing-page .navbar__logo img{width:219px}}@media(max-width:1050px){.navbar.landing-page{margin-bottom:0}}.navbar--hidden,.navbar.landing-page .landing-hide{display:none}.navbar--absolute{position:absolute}@media(max-width:1050px){.navbar{height:105px;align-items:flex-end}}@media(max-width:1050px){.navbar.navbar__button--watchlist a{color:var(--ion-color-primary)!important}}.navbar__logo{-webkit-padding-end:15px;padding-inline-end:15px;display:flex;align-items:center;flex-shrink:0}.navbar__logo img{width:131px}@media(max-width:1050px){.navbar__logo{position:absolute;top:0;width:100%;min-height:46px;display:flex;justify-content:center;align-items:center;margin:0;-webkit-padding-end:0;padding-inline-end:0}}.navbar--is-mobile .navbar__logo{justify-content:left}.navbar--is-ios .navbar__logo{height:56px}.navbar__logo-link{display:flex;align-items:center}.navbar__logo .valentine-link{font-size:24px;margin-top:2px;-webkit-margin-start:8px;margin-inline-start:8px}.navbar.container .navbar__logo{-webkit-margin-start:0;margin-inline-start:0;-webkit-padding-start:0;padding-inline-start:0}.navbar__search{z-index:1;flex-grow:2;height:52px;margin:0;-webkit-margin-end:7px;margin-inline-end:7px;display:flex}.navbar__search .search-suggester .searchbar-input{color:#fff;box-shadow:none;border-radius:4px;font-size:15px;padding:4px 0;-webkit-padding-start:50px;padding-inline-start:50px;-webkit-padding-end:15px;padding-inline-end:15px}@media(max-width:992px){.navbar__search--expanded{left:0;right:0;position:absolute}}.navbar.landing-page .navbar__search{flex-grow:0;width:35em;transition:width .6s;transition-delay:.1s;align-items:center;display:flex}.navbar.landing-page .navbar__search:focus-within{width:100%}@media(max-width:1050px){.navbar.landing-page .navbar__search:focus-within{display:flex;align-items:center;justify-content:space-around}}.navbar__extra{display:flex;min-width:92px}@media(max-width:1050px){.navbar__extra{display:none}}.navbar__extra__small{display:none}@media(max-width:1050px){.navbar__extra__small{display:block;position:absolute;top:0;width:100%}[dir=ltr] .navbar__extra__small{right:0}[dir=rtl] .navbar__extra__small{left:0}.navbar__extra__small--left{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--left{left:4px}[dir=rtl] .navbar__extra__small--left{right:4px}.navbar__extra__small--right{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--right{right:0}[dir=rtl] .navbar__extra__small--right{left:0}}.navbar__extra--remove-spacing{min-width:unset}.navbar__button{height:56px;flex-grow:inherit;cursor:pointer}.navbar__button a{padding:0}.navbar__button>div,.navbar__button__link{justify-content:center}.navbar__button__link{display:flex;align-items:center;height:100%;white-space:nowrap;font-size:14px;color:#999c9f}.navbar__button__link.nav-link-active,.navbar__button__link.router-link-exact-active{font-weight:700;color:#d9e8ed!important}.navbar__button__link__item{margin:0 15px;display:flex;-webkit-margin-end:15px;margin-inline-end:15px}@media(max-width:1050px){.navbar__button--home .navbar__button__link__item,.navbar__button--watchlist .navbar__button__link__item{display:none}}@media(max-width:1050px){.navbar__button--sports .navbar__button__link__item{margin:0 5px}}.navbar_ ...
# .freemium-filter__badge{display:inline-flex;align-items:center;font-size:14px;line-height:22px;letter-spacing:.2px;font-weight:700;text-align:center;color:#fff;background:linear-gradient(-225deg,#5c6374,#3b404e 31%,#272939 68%,#191d2a);padding:2px 7px;border-radius:4px;-webkit-margin-start:8px;margin-inline-start:8px}.freemium-filter__badge--sm{padding:2px 6px;font-size:12px;line-height:16px}.freemium-filter__badge svg{-webkit-margin-end:8px;margin-inline-end:8px}
# .search-suggester__results{overflow:scroll;border-bottom-left-radius:8px;border-bottom-right-radius:8px;height:90vh;max-width:100vw}.search-suggester{position:relative}.search-suggester .sponsored-recommendation-search{margin-top:-10px;z-index:1000;position:relative;display:flex;width:100%}.search-suggester input[type=search]::-webkit-search-cancel-button{display:none}.search-suggester__results{z-index:200;padding:0 8px 8px;margin:-9px 0 0}.search-suggester__results--mobile{padding:0;margin:-11px -1em -.4em}.search-suggester--web{text-align:start;width:100%;padding:0;height:52px;z-index:10}.search-suggester--web ion-searchbar.ios{--background:#10161d;padding:8px;height:52px}.search-suggester--web .searchbar-cancel-button.sc-ion-searchbar-ios{background:#10161d;-webkit-padding-end:8px;padding-inline-end:8px}.search-suggester__searchbar--mobile{padding-top:3px!important;padding-bottom:10px!important}.search-suggester__searchbar--mobile.md{height:52px;--background:#fff;--color:var(--ion-color-tertiary-shade)!important}.search-suggester__searchbar--mobile.md .searchbar-input{border-radius:4px!important}.search-suggester__searchbar input::-webkit-search-cancel-button{-webkit-appearance:none}.search-suggester__searchbar .searchbar-clear-icon{color:var(--ion-color-secondary)!important}.search-suggester__blocking{position:absolute;width:100%;padding:8px}.search-suggester__blocking__input{width:100%;height:38px;display:flex;align-items:center;background-color:var(--ion-color-tertiary-shade)}.searchbar-clear-button.sc-ion-searchbar-md{color:#fff!important}
# .logged-in[data-v-6aa447f4]{padding:0 15px;color:var(--ion-color-primary);font-size:18px}.logged-in[data-v-6aa447f4],.not-logged-in[data-v-6aa447f4]{height:100%;display:flex;align-items:center}@media(max-width:1050px){.not-logged-in__button[data-v-6aa447f4]{display:none}}.not-logged-in__icon[data-v-6aa447f4]{display:none;font-size:16px;cursor:pointer}@media(max-width:1050px){.not-logged-in__icon[data-v-6aa447f4]{display:block}}@media(max-width:1050px){.not-logged-in[data-v-6aa447f4]{padding:0 15px}}
# .basic-button{background:none;border:none;margin:0;padding:0;outline:none;white-space:nowrap;cursor:pointer}.basic-button__content{overflow:hidden;text-overflow:ellipsis}.basic-button.sm{font-size:13px;padding:.4rem 1.35rem}.basic-button.md{padding:.75rem 1.5rem}.basic-button.lg{font-size:18px;padding:1.6rem 4rem}.basic-button.lg.rounded{border-radius:8px}.basic-button.w-full{width:100%}.basic-button.rounded{border-radius:4px}.basic-button.uppercase{text-transform:uppercase}.basic-button.primary{font-weight:700;background-color:#fbc500;color:#000}.basic-button.primary.bg-none{color:#fbc500}.basic-button.primary.bg-none:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary.border{color:#fbcb1a;border:1px solid #fbcb1a}.basic-button.primary.border:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary:hover{background-color:#ddad00}.basic-button.secondary{color:#fff;font-weight:700;background-color:#4c5a67}.basic-button.secondary.bg-none{color:#4c5a67}.basic-button.secondary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary.border{border:1px solid #5e6b76}.basic-button.secondary.border:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary:hover{background-color:#ddad00}.basic-button.tertiary{color:#fff;background-color:#1c252f}.basic-button.tertiary.bg-none{color:#1c252f}.basic-button.tertiary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.tertiary.border{border:1px solid #383d47}.basic-button.tertiary.border:hover{background-color:rgba(56,61,71,.1)}.basic-button.tertiary:hover{background-color:#383d47}.basic-button.light{color:#d9e8ed;background-color:#1c252f}.basic-button.light:hover{background-color:#383d47}.basic-button.medium{color:#fff;background-color:#8c8c8c}.basic-button.medium.border{color:#999c9f;border:1px solid #999c9f}.basic-button.medium.border:hover{background-color:rgba(153,156,159,.1)}.basic-button.medium:hover{background-color:#999c9f}.basic-button.bg-none{background:transparent}.basic-button.disabled{cursor:default;opacity:.5;pointer-events:none}
# .navbar__button__link[data-v-701c8f36]{background:none;border:none;outline:none;cursor:pointer}
# .login-menu-button__button[data-v-4dfb297b]{all:unset;display:flex;align-items:center;height:100%;padding:0 15px;font-size:16px}.login-menu-button__button--logged-in[data-v-4dfb297b]{color:var(--ion-color-primary)}
# .popular-page__spinner{width:100%;height:50vh;display:flex;align-items:center;justify-content:center}#tyche_trendi_video_container.jw-no-consent{transform:translateY(-50px)}@media(max-width:768px){#tyche_trendi_video_container.jw-no-consent{transform:translateY(-100px)}}#tyche_trendi_video_container.jw-android-banner{transform:translateY(-80px)}.overlay-blocking-element{position:absolute;height:100vh;width:100vw}.content-provider-content{position:relative;width:100vw}.content-provider-content.full-height{min-height:100vh}.catalog-title{display:flex;align-items:center;justify-content:flex-start;width:100%}@media(max-width:1050px){.catalog-title h2{-webkit-margin-start:15px;margin-inline-start:15px}}.show-filters{margin:0 15px}@media(max-width:599px){.show-filters__text{display:none}}.sponsored-recommendation{grid-area:double-poster;height:100%}@media(max-width:540px){.sponsored-recommendation{height:270px}}
# .content[data-v-d7672432]{min-height:100vh;display:flex;flex-direction:column;--padding-top:56px}@media(max-width:1050px){.content[data-v-d7672432]{--padding-top:105px}}
# .toggle-filters{display:flex;align-items:center;margin:10px}.toggle-filters__label{-webkit-margin-end:5px;margin-inline-end:5px}.toggle-filters.border.bg-none{color:#d5d5d5}.content-container{display:flex;align-items:center;position:relative}.center-banner{display:flex;justify-content:center}.display-none{display:none}.content-header{min-height:138px;max-height:138px;overflow:hidden;position:relative;width:100%}@media(max-width:1050px){.content-header{padding-left:15px;padding-right:15px}}.content-header:hover{cursor:pointer}.content-header--expanded{max-height:none}.content-header--no-text{min-height:70px}.content-header--gradient{position:absolute;bottom:0;width:100%;text-align:center;margin:0;padding:15px 0;background-image:linear-gradient(180deg,rgba(6,13,23,0),var(--ion-background-color))}[dir=ltr] .content-header--gradient{left:0}[dir=rtl] .content-header--gradient{right:0}.content-header h1{-webkit-padding-end:15px;padding-inline-end:15px}.content-header__search-heading{flex-grow:1;display:flex;align-items:center}@media(max-width:1050px){.content-header__search-heading{padding-left:15px;padding-right:15px}}.content-header__search-heading h1{font-size:24px;line-height:32px;font-weight:700;color:#d9e8ed}@media(max-width:767px){.content-header__search-heading h1{font-size:16px;line-height:24px}}.content-header__search-heading div{font-size:15px;padding:10px 0 5px}.content-header__caret{position:absolute;top:18px}[dir=ltr] .content-header__caret{right:0}[dir=rtl] .content-header__caret{left:0}@media(max-width:1050px){[dir=ltr] .content-header__caret{right:20px}[dir=rtl] .content-header__caret{left:20px}}
# ...
#           </a>
#          </li>
#          <li class="jw-app-footer__link" data-v-01a44aa4="">
#           <a data-v-01a44aa4="" href="/in/guide/best-kriti-sanon-movies-where-to-watch">
#            10 Best Kriti Sanon Movies and Where to Stream Them
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </footer>
#      <!-- -->
#     </div>
#    </div>
#    <style>
#     null
#    </style>
#    <div>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#    </div>
#   </div>
#   <script data-vue-ssr-data="">
#    window.__DATA__={"state":{"app":{"geoLocation":"us","seoUser":true},"constant":{"providers":[{"clearName":"Netflix","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F207360008\u002F{profile}\u002Fnetflix.{format}","monetizationTypes":["FLATRATE"],"packageId":8,"selected":false,"shortName":"nfx","slug":"netflix","technicalName":"netflix"},{"clearName":"Amazon Prime Video","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F52449861\u002F{profile}\u002Famazonprimevideo.{format}","monetizationTypes":["FLATRATE"],"packageId":119,"selected":false,"shortName":"prv","slug":"amazon-prime-video","technicalName":"amazonprimevideo"},{"clearName":"Apple TV Plus","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F152862153\u002F{profile}\u002Fappletvplus.{format}","monetizationTypes":["FLATRATE"],"packageId":350,"selected":false,"shortName":"atp","slug":"apple-tv-plus","technicalName":"appletvplus"},{"clearName":"Apple TV","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F190848813\u002F{profile}\u002Fitunes.{format}","monetizationTypes":["BUY","RENT"],"packageId":2,"selected":false,"shortName":"itu","slug":"apple-tv","technicalName":"itunes"},{"clearName":"Crunchyroll","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F127445869\u002F{profile}\u002Fcrunchyroll.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":283,"selected":false,"shortName":"cru","slug":"crunchyroll","technicalName":"crunchyroll"},{"clearName":"Hotstar","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F240029443\u002F{profile}\u002Fhotstar.{format}","monetizationTypes":["FLATRATE"],"packageId":122,"selected":false,"shortName":"hst","slug":"hotstar","technicalName":"hotstar"},{"clearName":"Voot","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F4233119\u002F{profile}\u002Fvoot.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":121,"selected":false,"shortName":"voo","slug":"voot","technicalName":"voot"},{"clearName":"Jio Cinema","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F85114140\u002F{profile}\u002Fjiocinema.{format}","monetizationTypes":["FLATRATE"],"packageId":220,"selected":false,"shortName":"jio","slug":"jio-cinema","technicalName":"jiocinema"},{"clearName":"Zee5","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F93795879\u002F{profile}\u002Fzee5.{format}","monetizationTypes":["ADS","FLATRATE","FREE"],"packageId":232,"selected":false,"shortName":"zee","slug":"zee5","technicalName":"zee5"},{"clearName":"Eros Now","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F247912837\u002F{profile}\u002Ferosnow.{format}","monetizationTypes":["FLATRATE"],"packageId":218,"selected":false,"shortName":"ern","slug":"eros-now","technicalName":"erosnow"},{"clearName":"Google Play Movies","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F169478387\u002F{profile}\u002Fplay.{format}","monetizationTypes":["BUY","RENT"],"packageId":3,"selected":false,"shortName":"ply","slug":"google-play-movies","technicalName":"play"},{"clearName":"MUBI","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F164970114\u002F{profile}\u002Fmubi.{format}","monetizationTypes":["FLATRATE","RENT"],"packageId":11,"selected":false,"shortName":"mbi","slug":"mubi","technicalName":"mubi"},{"clearName":"Sony Liv","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F207468084\u002F{profile}\u002Fsonyliv.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":237,"selected":false,"shortName":"snl","slug":"sony-liv","technicalName":"sonyliv"},{"clearName":"YouTube","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F59562423\u002F{profile}\u002Fyoutube.{format}","monetizationTypes":["BUY","FLATRATE","RENT"],"packageId":192,"selected":false,"shortName":"yot","slug":"youtube","technicalName":"youtube"},{"clearName":"GuideDoc","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F2625277\u002F{profile}\u002Fguidedoc.{format}","monetizationTypes":["FLATRATE"],"packageId":100,"selected":false,"shor ...
#   </script>
#   <script>
#    window.__APOLLO_STATE__={"defaultClient":{"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY":{"ageCertifications({\"country\":\"IN\"})":[{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13","typename":"AgeCertification"}],"ageCertifications({\"country\":\"IN\",\"objectType\":\"MOVIE\"})":[{"type":"id","generated":false,"id":"AgeCertification:27","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:28","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:29","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21388","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21405","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21427","typename":"AgeCertification"},{"type":"id","generated":false ...
#   </script>
#   <script>
#    // Runtime Env Vars
# 			window.DNS_PREFETCH=[{"rel":"dns-prefetch","href":"https://www.googletagmanager.com/"},{"rel":"dns-prefetch","href":"https://ib.adnxs.com"}];
# 			window.HTTP_PRECONNECT=[{"rel":"preconnect","crossorigin":"use-credentials","href":"https://images.justwatch.com"}];
# 			window.BUILD_CONFIG={"appVersion":"3.8.2","commitHash":"20e5756e8da75867e5a482ada39a796fcaf99c3b","commitShortHash":"20e5756","env":"prod","globals":{"ASSETS_DIR":"appassets","BUILD_TARGET":"SSR","IS_BUILD":true,"IS_SERVE":false,"IS_START":false,"IS_DEV":true,"IS_PROD":false}};
# 			window.JW_CONFIG={"API":"https://apis.justwatch.com/content","ASSETS_URL":"https://www.justwatch.com/static/compile_jw/assets","BRAZE_BASE_URL":"sdk.iad-05.braze.com","BRAZE_WEB_API_KEY":"1aad19f0-6f9f-4fd5-9a05-9ca5499795f9","CHECKIP_URL":"https://info.justwatch.com ","CLICK_URL":"https://click.justwatch.com","DISCOVERY_URL":"https://apis.justwatch.com/discovery","DOMAIN":"justwatch.com","EVENT_URL":"https://apis.justwatch.com/event","EXPERIMENT_CONFIG_URL":"https://apis.justwatch.com/configuration/experiments","FACEBOOK_APP_ID":"794243977319785","FEEDBACK_URL":"https://apis.justwatch.com/feedback","FIREBASE_API_KEY":"AIzaSyDv6JIzdDvbTBS-JWdR4Kl22UvgWGAyuo8","FIREBASE_APP_ID":"1:413470318987:web:28b910bbf217d7d5034f8e","FIREBASE_AUTH_DOMAIN":"accounts.justwatch.com","FIREBASE_MESSAGING_SENDER_ID":"413470318987","FIREBASE_PROJECT_ID":"justwatch-apps-beta","FIREBASE_STORAGE_BUCKET":"justwatch-apps-beta.appspot.com","GOOGLE_CLIENT_ID":"532718895899-fhbuhnd9nsrae0ivadejq35vsr2sgr0l.apps.googleusercontent.com","GOOGLE_MAPS_API_KEY":"AIzaSyBVU86Zuf3v_6W8dnnV9BRKe_YSBXroqCA","GRAPHQL_URL":"https://apis.justwatch.com/graphql","IDENTITY_URL":"https://apis.justwatch.com/identity","ID_URL":"https://i.tw.cx","IMAGESCALER_FAST_URL":"https://www.justwatch.com/images","IMAGESCALER_URL":"https://images.justwatch.com","JOBSITE_URL":"https://www.justwatch.com/talent/jobs","ITUNES_APP_ID":"979227482","NOTIFICATION_URL":"https://apis.justwatch.com/notification","PLOT_RECOMMENDER_URL":"https://apis.justwatch.com/plotpoint","REVENUE_CAT_API_URL":"https://api.revenuecat.com/v1","REVENUE_CAT_PUBLIC_KEY":"sijZLciaBRrTwuIAeBkAqzQNtMNQaXqV","SENTRY_DSN":"https://ad6b9c4b3a3f4e998e38c3c7ed92574f@sentry.justwatch.com/4","SENTRY_DSN_SSR_CLIENT":"https://e83b625f73464fe9af5aea210630233c@sentry.justwatch.com/9","SNOWPLOW_COLLECTOR_ENDPOINT":"sp.justwatch.com","USER_URL":"https://userapi.justwatch.com","WRITE_URL":"https://apis.justwatch.com/personalization","AD_TAG":"https://pubads.g.doubleclick.net/gampad/ads?iu=/21679119891/video_ads_trailers&description_url=https%3A%2F%2Fwww.justwatch.com%2F&tfcd=0&npa=0&sz=640x360%7C640x480&gdfp_req=1&output=vast&unviewed_position_start=1&env=vp&impl=s&correlator=&vad_type=linear","ZENDESK_SUBDOMAIN":"https://justwatch.zendesk.com","SUBSCRIPTIONS":{"regular":{"id":"prod_LKEY8MLBOZwwQN","priceId":"price_1Kda5MKD0TTmBHo0KnyileCK","type":"regular","timeframe":"monthly","price":2.49},"yearly":{"id":"prod_NzlZqI8lGP1soA","priceId":"price_1NDm2ZKD0TTmBHo0u99J14yr","type":"yearly","timeframe":"yearly","price":19.99},"monthly":{"id":"prod_NzlSDe5AXBSi4X","priceId":"price_1NDlvNKD0TTmBHo08pBWfjIZ","type":"monthly","timeframe":"monthly","price":3.99},"onetime":{"id":"prod_NzlbbPqyeBPsT8","priceId":"price_1NDm4CKD0TTmBHo0KnsX1AJw","type":"onetime","timeframe":"one time","price":59.99}}};
# 			window.IMG_POSTER_LOAD_COUNT=4;
# 			window.IMG_PROVIDERS_BAR_LOAD_COUNT=7;
# 			window.IMG_PROVIDERS_BUY_BOX_COUNT=6;
# 			window.IMG_NEW_TIMELINE_ROWS=1;
# 			window.IS_CANARY=false;
# 			window.NEW_TIMELINE_BUCKETS_LIMIT=4;
# 			window.NEW_TIMELINE_TITLES_PER_BUCKET_LIMIT=10;
# 			window.VUE_APP_TESTS_E2E=false;
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_runtime.ec870570.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_popular.85852750.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_chunk-48f5c245.0c44ec24.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_title-list-grid.53749718.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_chunk-09eadbc1.4f506bd4.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_default-footer.25da163f.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_low-priority-components.0e781e3d.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.vue.53092bae.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.vue-router.3d04e099.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.firebase.3638ea87.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.graphql.f600a27c.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.sentry.6d850964.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.sentry-internal.b5967eab.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.fortawesome.0f6b93f7.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.apollo-client.25b9e10b.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.localforage.67c908d6.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_app.4f3244db.js" type="module">
#   </script>
#   <script>
#    !function(){var e=document,t=e.createElement("script");if(!("noModule"in t)&&"onbeforeload"in t){var n=!1;e.addEventListener("beforeload",function(e){if(e.target===t)n=!0;else if(!e.target.hasAttribute("nomodule")||!n)return;e.preventDefault()},!0),t.type="module",t.src=".",e.head.appendChild(t),t.remove()}}();
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_runtime.cf763861.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.vue.53092bae.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.vue-router.3d04e099.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.firebase.3638ea87.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.node-libs-browser.84e0af7d.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.graphql.f600a27c.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.sentry.6d850964.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.sentry-internal.b5967eab.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.uvue.2246dd71.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.fortawesome.0f6b93f7.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.apollo-client.25b9e10b.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.localforage.67c908d6.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_app.570c2c4d.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# Finding all anchor elements with the specified class
anchor_elements = soup.find_all('a', class_='title-list-grid__item--link')

# Initializing an empty list to store the movie URLs
movie_urls = []

# Loop through each anchor element and extract the 'href' attribute
for anchor_element in anchor_elements:
  href_value = anchor_element.get('href')
  full_url = f'https://www.justwatch.com{href_value}'
  movie_urls.append(full_url)

# Printing the list of movie URLs
print(movie_urls)
# Out:
# ['https://www.justwatch.com/in/movie/animal-2022', 'https://www.justwatch.com/in/movie/12th-fail', 'https://www.justwatch.com/in/movie/salaar', 'https://www.justwatch.com/in/movie/sam-bahadur', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom', 'https://www.justwatch.com/in/movie/tiger-3', 'https://www.justwatch.com/in/movie/nani30', 'https://www.justwatch.com/in/movie/oppenheimer', 'https://www.justwatch.com/in/movie/hanu-man', 'https://www.justwatch.com/in/movie/mission-impossible-7', 'https://www.justwatch.com/in/movie/dunki', 'https://www.justwatch.com/in/movie/killers-of-the-flower-moon', 'https://www.justwatch.com/in/movie/parking-2023', 'https://www.justwatch.com/in/movie/devil-2023', 'https://www.justwatch.com/in/movie/jawan', 'https://www.justwatch.com/in/movie/sapta-sagaradaache-ello-side-b', 'https://www.justwatch.com/in/movie/the-kerala-story', 'https://www.justwatch.com/in/movie/guthlee-ladoo', 'https://www.justwatch.com/in/movie/neru', 'https://www.justwatch.com/in/movie/barbie-2023', 'https://www.justwatch.com/in/movie/society-of-the-snow', 'https://www.justwatch.com/in/movie/lift-0', 'https://www.justwatch.com/in/movie/the-marvels', 'https://www.justwatch.com/in/movie/anatomie-dune-chute', 'https://www.justwatch.com/in/movie/fighter-2022', 'https://www.justwatch.com/in/movie/kaathal-the-core', 'https://www.justwatch.com/in/movie/the-beekeeper-2024', 'https://www.justwatch.com/in/movie/anyone-but-you', 'https://www.justwatch.com/in/movie/poor-things', 'https://www.justwatch.com/in/movie/saltburn', 'https://www.justwatch.com/in/movie/ssmb-28', 'https://www.justwatch.com/in/movie/migration', 'https://www.justwatch.com/in/movie/talk-to-me-2022', 'https://www.justwatch.com/in/movie/napoleon-2023', 'https://www.justwatch.com/in/movie/mangalavaram', 'https://www.justwatch.com/in/movie/past-lives', 'https://www.justwatch.com/in/movie/joram', 'https://www.justwatch.com/in/movie/leo-2023', 'https://www.justwatch.com/in/movie/the-family-plan', 'https://www.justwatch.com/in/movie/saindhav', 'https://www.justwatch.com/in/movie/merry-christmas-2024', 'https://www.justwatch.com/in/movie/kho-gaye-hum-kahan', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone', 'https://www.justwatch.com/in/movie/interstellar', 'https://www.justwatch.com/in/movie/joe-2023', 'https://www.justwatch.com/in/movie/chittha', 'https://www.justwatch.com/in/movie/the-holdovers', 'https://www.justwatch.com/in/movie/jigarthanda-doublex', 'https://www.justwatch.com/in/movie/777-charlie', 'https://www.justwatch.com/in/movie/rocky-aur-rani-ki-prem-kahani', 'https://www.justwatch.com/in/movie/dada-2023', 'https://www.justwatch.com/in/movie/mad-max-fury-road', 'https://www.justwatch.com/in/movie/365-days', 'https://www.justwatch.com/in/movie/three-of-us', 'https://www.justwatch.com/in/movie/extra', 'https://www.justwatch.com/in/movie/zara-hatke-zara-bach-ke', 'https://www.justwatch.com/in/movie/wonka', 'https://www.justwatch.com/in/movie/role-play-2023', 'https://www.justwatch.com/in/movie/antony-2023', 'https://www.justwatch.com/in/movie/blue-beetle', 'https://www.justwatch.com/in/movie/annapoorani', 'https://www.justwatch.com/in/movie/the-wolf-of-wall-street', 'https://www.justwatch.com/in/movie/gadar-2', 'https://www.justwatch.com/in/movie/tejas', 'https://www.justwatch.com/in/movie/inception', 'https://www.justwatch.com/in/movie/pindam', 'https://www.justwatch.com/in/movie/starfish-2023', 'https://www.justwatch.com/in/movie/the-creator', 'https://www.justwatch.com/in/movie/aquaman', 'https://www.justwatch.com/in/movie/joker-2019', 'https://www.justwatch.com/in/movie/dumb-money', 'https://www.justwatch.com/in/movie/the-batman', 'https://www.justwatch.com/in/movie/toby', 'https://www.justwatch.com/in/movie/badland-hunters', 'https://www.justwatch.com/in/movie/atharva', 'https://www.justwatch.com/in/movie/yaariyan-2', 'https://www.justwatch.com/in/movie/godzilla-minus-one', 'https://www.justwatch.com/in/movie/uri-the-s ...

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# Initializing an empty list to store movie titles
movie_title = []

# Iterating through each anchor element in the list
for anchor_element in anchor_elements:
    # Extracting the movie title from the 'href' attribute of the anchor element
    name = anchor_element.get('href').split('/')[-1].strip()

    # Appending the movie title to the 'movie_title' list
    movie_title.append(name)

# Printing the list of movie titles
print(movie_title)
# Out:
# ['animal-2022', '12th-fail', 'salaar', 'sam-bahadur', 'aquaman-and-the-lost-kingdom', 'tiger-3', 'nani30', 'oppenheimer', 'hanu-man', 'mission-impossible-7', 'dunki', 'killers-of-the-flower-moon', 'parking-2023', 'devil-2023', 'jawan', 'sapta-sagaradaache-ello-side-b', 'the-kerala-story', 'guthlee-ladoo', 'neru', 'barbie-2023', 'society-of-the-snow', 'lift-0', 'the-marvels', 'anatomie-dune-chute', 'fighter-2022', 'kaathal-the-core', 'the-beekeeper-2024', 'anyone-but-you', 'poor-things', 'saltburn', 'ssmb-28', 'migration', 'talk-to-me-2022', 'napoleon-2023', 'mangalavaram', 'past-lives', 'joram', 'leo-2023', 'the-family-plan', 'saindhav', 'merry-christmas-2024', 'kho-gaye-hum-kahan', 'harry-potter-and-the-philosophers-stone', 'interstellar', 'joe-2023', 'chittha', 'the-holdovers', 'jigarthanda-doublex', '777-charlie', 'rocky-aur-rani-ki-prem-kahani', 'dada-2023', 'mad-max-fury-road', '365-days', 'three-of-us', 'extra', 'zara-hatke-zara-bach-ke', 'wonka', 'role-play-2023', 'antony-2023', 'blue-beetle', 'annapoorani', 'the-wolf-of-wall-street', 'gadar-2', 'tejas', 'inception', 'pindam', 'starfish-2023', 'the-creator', 'aquaman', 'joker-2019', 'dumb-money', 'the-batman', 'toby', 'badland-hunters', 'atharva', 'yaariyan-2', 'godzilla-minus-one', 'uri-the-surgical-strike', 'fast-x', 'dune-2021', 'batman-begins', 'captain-miller', 'the-dark-knight', 'dd-returns', 'andhadhun', 'dunkirk', 'pushpa', 'ayalaan', 'pathaan', 'the-zone-of-interest', 'the-flash', 'blade-runner-2049', 'spider-man-into-the-spider-verse-2', '96', 'k-g-f-chapter-2', 'ala-vaikunthapurramuloo', 'blood-diamond', 'falimy', 'top-gun-maverick', 'the-kid-who-would-be-king']

# %% [markdown]
# ## **Scrapping release Year**

# %%
# Initializing an empty list to store release years
release_year = []

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the span element with class 'text-muted'
    year = soup.find('span', class_='text-muted')

    # Extracting the release year using string manipulation
    # If 'year' is not found, assign 'NA' as the default value
    release_year.append(year.text.split("(")[-1].split(")")[0] if year else 'NA')

# Printing the list of release years
print(release_year)
# Out:
# ['2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2024', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2024', '2023', '2023', '2024', '2023', '2024', '2023', '2023', '2023', '2024', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2024', '2024', '2023', '2001', '2014', '2023', '2023', '2023', '2023', '2022', '2023', '2023', '2015', '2020', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2013', '2023', '2023', '2010', '2023', '2023', '2023', '2018', '2019', '2023', '2022', '2023', '2024', '2023', '2023', '2023', '2019', '2023', '2021', '2005', '2024', '2008', '2023', '2018', '2017', '2021', '2024', '2023', '2023', '2023', '2017', '2023', '2018', '2022', '2020', '2006', '2023', '2022', '2019']

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Initializing an empty list to store movie genres
movie_genres = []

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the h3 element with class 'detail-infos__subheading' and text 'Genres'
    heading = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    # Extracting the text of the next sibling div element with class 'detail-infos__value'
    genre_value = heading.find_next_sibling('div', class_='detail-infos__value').text.strip()

    # Appending the extracted genre to the list
    movie_genres.append(genre_value)

# Printing the list of movie genres
print(movie_genres)
# Out:
# ['Action & Adventure, Drama, Crime, Mystery & Thriller', 'Drama', 'Action & Adventure, Crime, Drama, Mystery & Thriller', 'War & Military, Drama, History', 'Action & Adventure, Fantasy, Science-Fiction', 'Action & Adventure, Mystery & Thriller', 'Drama, Kids & Family, Romance', 'Drama, History', 'Fantasy, Action & Adventure, Comedy, Science-Fiction', 'Action & Adventure, Mystery & Thriller', 'Comedy, Drama', 'Crime, History, Drama, Romance, Western', 'Mystery & Thriller, Drama', 'Mystery & Thriller, Action & Adventure, Drama', 'Mystery & Thriller, Action & Adventure', 'Romance, Drama', 'Drama', 'Drama', 'Drama, Mystery & Thriller', 'Fantasy, Comedy', 'Drama, History, Mystery & Thriller', 'Crime, Mystery & Thriller, Action & Adventure, Comedy, Drama', 'Action & Adventure, Science-Fiction, Fantasy', 'Drama, Mystery & Thriller, Crime', 'Mystery & Thriller, Action & Adventure, War & Military', 'Drama, Crime', 'Action & Adventure, Mystery & Thriller, Drama', 'Comedy, Romance', 'Comedy, Science-Fiction, Romance, Drama', 'Mystery & Thriller, Drama, Comedy', 'Drama, Kids & Family, Action & Adventure', 'Animation, Action & Adventure, Comedy, Kids & Family, Fantasy', 'Horror, Mystery & Thriller', 'Drama, History, War & Military, Action & Adventure', 'Action & Adventure, Horror, Mystery & Thriller', 'Drama, Romance', 'Drama, Mystery & Thriller, Action & Adventure, Crime', 'Action & Adventure, Crime, Mystery & Thriller, Drama', 'Action & Adventure, Comedy', 'Action & Adventure, Crime, Drama, Mystery & Thriller', 'Drama, Mystery & Thriller', 'Comedy, Drama, Romance', 'Fantasy, Action & Adventure, Kids & Family', 'Drama, Science-Fiction, Action & Adventure', 'Drama', 'Drama, Mystery & Thriller', 'Drama, Comedy', 'Comedy, Drama, Action & Adventure', 'Comedy, Drama', 'Comedy, Drama, Kids & Family, Romance', 'Comedy, Romance, Drama, Kids & Family', 'Action & Adventure, Science-Fiction, Mystery & Thriller', 'Romance, Drama, Made in Europe', 'Drama', 'Drama, Action & Adventure', 'Drama, Romance, Comedy, Kids & Family', 'Comedy, Fantasy, Kids & Family', 'Romance, Action & Adventure, Comedy', 'Action & Adventure, Drama, Kids & Family, Mystery & Thriller', 'Action & Adventure, Science-Fiction, Mystery & Thriller', 'Comedy, Drama', 'Comedy, Crime, Drama', 'Action & Adventure, Drama, Mystery & Thriller', 'Action & Adventure, Drama, Mystery & Thriller', 'Action & Adventure, Science-Fiction, Mystery & Thriller', 'Horror, Mystery & Thriller', 'Drama, Mystery & Thriller, Romance', 'Action & Adventure, Science-Fiction, Drama, Mystery & Thriller', 'Action & Adventure, Fantasy, Science-Fiction', 'Mystery & Thriller, Crime, Drama', 'Comedy, Drama, History', 'Mystery & Thriller, Drama, Action & Adventure, Crime', 'Action & Adventure, Mystery & Thriller, Drama, Crime', 'Drama, Action & Adventure, Science-Fiction, Mystery & Thriller', 'Mystery & Thriller, Crime, Drama', 'Romance, Drama, Kids & Family, Comedy', 'Horror, Action & Adventure, Science-Fiction, Drama', 'War & Military, Action & Adventure, Drama, History', 'Action & Adventure, Crime, Mystery & Thriller', 'Science-Fiction, Drama, Action & Adventure', 'Action & Adventure, Drama, Crime', 'Action & Adventure, Drama, Mystery & Thriller', 'Crime, Mystery & Thriller, Drama, Action & Adventure', 'Horror, Comedy', 'Mystery & Thriller, Comedy, Crime, Music & Musical', 'Action & Adventure, War & Military, Drama, History, Mystery & Thriller', 'Drama, Mystery & Thriller, Action & Adventure, Crime', 'Science-Fiction, Action & Adventure', 'Mystery & Thriller, Drama, Action & Adventure', 'Drama, History, War & Military', 'Action & Adventure, Science-Fiction, Fantasy', 'Drama, Science-Fiction, Action & Adventure, Mystery & Thriller', 'Science-Fiction, Animation, Action & Adventure, Comedy, Kids & Family, Fantasy', 'Romance, Drama', 'Action & Adventure, Crime, Drama, Mystery & Thriller', 'Comedy, Drama, Action & Adventure', 'Drama, Mystery & Thriller, Action & Adventure', 'Drama', 'Action & Adventure, Drama', 'Action & ...

# %% [markdown]
# ## **scrapping IMBD Rating**

# %%
# Initializing a dictionary to store rating values for each movie URL
ratings = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for rating in case it's not found
    rating_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Rating'
        if subheading and 'Rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            rating_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the rating_div is found
            if rating_div:
                # Extracting the rating value
                rating_value = rating_div.text.strip()

    # Storing the rating value in the dictionary with the movie URL as the key
    ratings[url] = rating_value

# Print the dictionary containing rating values for each movie URL
print(ratings)
# Out:
# {'https://www.justwatch.com/in/movie/animal-2022': '6.4  (76k)', 'https://www.justwatch.com/in/movie/12th-fail': '9.2  (90k)', 'https://www.justwatch.com/in/movie/salaar': '6.6  (56k)', 'https://www.justwatch.com/in/movie/sam-bahadur': '7.9  (11k)', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': '5.7  (49k)', 'https://www.justwatch.com/in/movie/tiger-3': '6.0  (51k)', 'https://www.justwatch.com/in/movie/nani30': '8.3  (11k)', 'https://www.justwatch.com/in/movie/oppenheimer': '8.4  (624k)', 'https://www.justwatch.com/in/movie/hanu-man': '8.5  (16k)', 'https://www.justwatch.com/in/movie/mission-impossible-7': '7.7  (220k)', 'https://www.justwatch.com/in/movie/dunki': '7.2  (62k)', 'https://www.justwatch.com/in/movie/killers-of-the-flower-moon': '7.7  (191k)', 'https://www.justwatch.com/in/movie/parking-2023': '7.9  (8k)', 'https://www.justwatch.com/in/movie/devil-2023': '6.7  (2k)', 'https://www.justwatch.com/in/movie/jawan': '7.0  (90k)', 'https://www.justwatch.com/in/movie/sapta-sagaradaache-ello-side-b': '8.1  (2k)', 'https://www.justwatch.com/in/movie/the-kerala-story': '7.2  (66k)', 'https://www.justwatch.com/in/movie/guthlee-ladoo': '7.7', 'https://www.justwatch.com/in/movie/neru': '7.7  (4k)', 'https://www.justwatch.com/in/movie/barbie-2023': '6.9  (479k)', 'https://www.justwatch.com/in/movie/society-of-the-snow': '7.9  (87k)', 'https://www.justwatch.com/in/movie/lift-0': '5.5  (29k)', 'https://www.justwatch.com/in/movie/the-marvels': '', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': '7.8  (56k)', 'https://www.justwatch.com/in/movie/fighter-2022': '7.8  (31k)', 'https://www.justwatch.com/in/movie/kaathal-the-core': '7.6  (2k)', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': '6.5  (35k)', 'https://www.justwatch.com/in/movie/anyone-but-you': '6.7  (14k)', 'https://www.justwatch.com/in/movie/poor-things': '8.4  (70k)', 'https://www.justwatch.com/in/movie/saltburn': '7.1  (159k)', 'https://www.justwatch.com/in/movie/ssmb-28': '6.2  (17k)', 'https://www.justwatch.com/in/movie/migration': '6.7  (12k)', 'https://www.justwatch.com/in/movie/talk-to-me-2022': '7.1  (128k)', 'https://www.justwatch.com/in/movie/napoleon-2023': '6.4  (104k)', 'https://www.justwatch.com/in/movie/mangalavaram': '6.7  (1k)', 'https://www.justwatch.com/in/movie/past-lives': '7.9', 'https://www.justwatch.com/in/movie/joram': '6.9  (1k)', 'https://www.justwatch.com/in/movie/leo-2023': '7.2  (56k)', 'https://www.justwatch.com/in/movie/the-family-plan': '6.3  (33k)', 'https://www.justwatch.com/in/movie/saindhav': '5.3', 'https://www.justwatch.com/in/movie/merry-christmas-2024': '7.9  (18k)', 'https://www.justwatch.com/in/movie/kho-gaye-hum-kahan': '7.7  (27k)', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': '7.6  (847k)', 'https://www.justwatch.com/in/movie/interstellar': '8.7  (2m)', 'https://www.justwatch.com/in/movie/joe-2023': '7.7  (1k)', 'https://www.justwatch.com/in/movie/chittha': '8.3  (5k)', 'https://www.justwatch.com/in/movie/the-holdovers': 'NA', 'https://www.justwatch.com/in/movie/jigarthanda-doublex': '8.1  (8k)', 'https://www.justwatch.com/in/movie/777-charlie': '8.8  (38k)', 'https://www.justwatch.com/in/movie/rocky-aur-rani-ki-prem-kahani': '6.6  (41k)', 'https://www.justwatch.com/in/movie/dada-2023': '8.2  (5k)', 'https://www.justwatch.com/in/movie/mad-max-fury-road': '8.1  (1m)', 'https://www.justwatch.com/in/movie/365-days': '3.3  (97k)', 'https://www.justwatch.com/in/movie/three-of-us': '7.6  (2k)', 'https://www.justwatch.com/in/movie/extra': '5.2  (1k)', 'https://www.justwatch.com/in/movie/zara-hatke-zara-bach-ke': '6.4  (8k)', 'https://www.justwatch.com/in/movie/wonka': '7.2  (86k)', 'https://www.justwatch.com/in/movie/role-play-2023': '5.4', 'https://www.justwatch.com/in/movie/antony-2023': '6.8', 'https://www.justwatch.com/in/movie/blue-beetle': '6.0  (87k)', 'https://www.justwatch.com/in/movie/annapoorani': '3.6  (5k)', 'https://www.justwatch.com/in/movie/the-wo ...

# %%
# Initializing an empty list to store IMDb ratings
imdb_ratings = []

# Iterate through each value in the 'ratings' dictionary
for rating in ratings.values():
    # Check if the rating is not 'NA'
    if rating != 'NA':
        # Split the rating string and append the IMDb rating part to the list
        imdb_ratings.append(rating.split(' ')[0])
    else:
        # If the rating is 'NA', append it directly to the list
        imdb_ratings.append(rating)

# Print the list of IMDb ratings
print(imdb_ratings)
# Out:
# ['6.4', '9.2', '6.6', '7.9', '5.7', '6.0', '8.3', '8.4', '8.5', '7.7', '7.2', '7.7', '7.9', '6.7', '7.0', '8.1', '7.2', '7.7', '7.7', '6.9', '7.9', '5.5', '', '7.8', '7.8', '7.6', '6.5', '6.7', '8.4', '7.1', '6.2', '6.7', '7.1', '6.4', '6.7', '7.9', '6.9', '7.2', '6.3', '5.3', '7.9', '7.7', '7.6', '8.7', '7.7', '8.3', 'NA', '8.1', '8.8', '6.6', '8.2', '8.1', '3.3', '7.6', '5.2', '6.4', '7.2', '5.4', '6.8', '6.0', '3.6', '8.2', '5.2', '5.3', '8.8', '8.4', '6.0', '6.8', '6.8', '8.4', '6.9', '7.8', '7.4', '6.0', '7.7', '6.1', '8.3', '8.2', '5.8', '8.0', '8.2', '7.3', '9.0', '6.2', '8.2', '7.8', '7.6', '6.4', '5.9', '7.9', '6.7', '8.0', '8.6', '8.5', '8.3', '7.3', '8.0', '7.3', '8.3', '6.1']

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Initializing a dictionary to store runtime values for each movie URL
runtime = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for runtime in case it's not found
    runtime_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Runtime'
        if subheading and 'Runtime' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            runtime_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the runtime_div is found
            if runtime_div:
                # Extracting the runtime value
                runtime_value = runtime_div.text.strip()

    # Storing the runtime value in the dictionary with the movie URL as the key
    runtime[url] = runtime_value

# Print the dictionary containing runtime values for each movie URL
print(runtime)
# Out:
# {'https://www.justwatch.com/in/movie/animal-2022': '3h 21min', 'https://www.justwatch.com/in/movie/12th-fail': '2h 26min', 'https://www.justwatch.com/in/movie/salaar': '2h 55min', 'https://www.justwatch.com/in/movie/sam-bahadur': '2h 30min', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': '2h 4min', 'https://www.justwatch.com/in/movie/tiger-3': '2h 35min', 'https://www.justwatch.com/in/movie/nani30': '2h 35min', 'https://www.justwatch.com/in/movie/oppenheimer': '3h 1min', 'https://www.justwatch.com/in/movie/hanu-man': '2h 39min', 'https://www.justwatch.com/in/movie/mission-impossible-7': '2h 44min', 'https://www.justwatch.com/in/movie/dunki': '2h 40min', 'https://www.justwatch.com/in/movie/killers-of-the-flower-moon': '3h 26min', 'https://www.justwatch.com/in/movie/parking-2023': '2h 7min', 'https://www.justwatch.com/in/movie/devil-2023': '2h 24min', 'https://www.justwatch.com/in/movie/jawan': '2h 49min', 'https://www.justwatch.com/in/movie/sapta-sagaradaache-ello-side-b': '2h 28min', 'https://www.justwatch.com/in/movie/the-kerala-story': '2h 18min', 'https://www.justwatch.com/in/movie/guthlee-ladoo': '1h 45min', 'https://www.justwatch.com/in/movie/neru': '2h 30min', 'https://www.justwatch.com/in/movie/barbie-2023': '1h 54min', 'https://www.justwatch.com/in/movie/society-of-the-snow': '2h 24min', 'https://www.justwatch.com/in/movie/lift-0': '1h 46min', 'https://www.justwatch.com/in/movie/the-marvels': '1h 45min', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': '2h 32min', 'https://www.justwatch.com/in/movie/fighter-2022': '2h 47min', 'https://www.justwatch.com/in/movie/kaathal-the-core': '1h 52min', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': '1h 45min', 'https://www.justwatch.com/in/movie/anyone-but-you': '1h 43min', 'https://www.justwatch.com/in/movie/poor-things': '2h 21min', 'https://www.justwatch.com/in/movie/saltburn': '2h 11min', 'https://www.justwatch.com/in/movie/ssmb-28': '2h 39min', 'https://www.justwatch.com/in/movie/migration': '1h 23min', 'https://www.justwatch.com/in/movie/talk-to-me-2022': '1h 35min', 'https://www.justwatch.com/in/movie/napoleon-2023': '2h 38min', 'https://www.justwatch.com/in/movie/mangalavaram': '2h 25min', 'https://www.justwatch.com/in/movie/past-lives': '1h 46min', 'https://www.justwatch.com/in/movie/joram': '1h 57min', 'https://www.justwatch.com/in/movie/leo-2023': '2h 43min', 'https://www.justwatch.com/in/movie/the-family-plan': '1h 59min', 'https://www.justwatch.com/in/movie/saindhav': '2h 18min', 'https://www.justwatch.com/in/movie/merry-christmas-2024': '2h 24min', 'https://www.justwatch.com/in/movie/kho-gaye-hum-kahan': '2h 15min', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': '2h 32min', 'https://www.justwatch.com/in/movie/interstellar': '2h 49min', 'https://www.justwatch.com/in/movie/joe-2023': '2h 27min', 'https://www.justwatch.com/in/movie/chittha': '2h 20min', 'https://www.justwatch.com/in/movie/the-holdovers': '2h 13min', 'https://www.justwatch.com/in/movie/jigarthanda-doublex': '2h 52min', 'https://www.justwatch.com/in/movie/777-charlie': '2h 46min', 'https://www.justwatch.com/in/movie/rocky-aur-rani-ki-prem-kahani': '2h 48min', 'https://www.justwatch.com/in/movie/dada-2023': '2h 15min', 'https://www.justwatch.com/in/movie/mad-max-fury-road': '2h 1min', 'https://www.justwatch.com/in/movie/365-days': '1h 54min', 'https://www.justwatch.com/in/movie/three-of-us': '1h 39min', 'https://www.justwatch.com/in/movie/extra': '2h 35min', 'https://www.justwatch.com/in/movie/zara-hatke-zara-bach-ke': '2h 20min', 'https://www.justwatch.com/in/movie/wonka': '1h 57min', 'https://www.justwatch.com/in/movie/role-play-2023': '1h 41min', 'https://www.justwatch.com/in/movie/antony-2023': '2h 27min', 'https://www.justwatch.com/in/movie/blue-beetle': '2h 8min', 'https://www.justwatch.com/in/movie/annapoorani': '2h 26min', 'https://www.justwatch.com/in/movie/the-wolf-of-wall-street': '3h 0min', 'https://www.justwatch.com/in/movi ...

# %%
# Initializing an empty list to store duration values
duration = []

# Iterate through each value in the 'runtime' dictionary
for time in runtime.values():
    # Append the runtime value to the 'duration' list
    duration.append(time)

# Print the list of duration values
print(duration)
# Out:
# ['3h 21min', '2h 26min', '2h 55min', '2h 30min', '2h 4min', '2h 35min', '2h 35min', '3h 1min', '2h 39min', '2h 44min', '2h 40min', '3h 26min', '2h 7min', '2h 24min', '2h 49min', '2h 28min', '2h 18min', '1h 45min', '2h 30min', '1h 54min', '2h 24min', '1h 46min', '1h 45min', '2h 32min', '2h 47min', '1h 52min', '1h 45min', '1h 43min', '2h 21min', '2h 11min', '2h 39min', '1h 23min', '1h 35min', '2h 38min', '2h 25min', '1h 46min', '1h 57min', '2h 43min', '1h 59min', '2h 18min', '2h 24min', '2h 15min', '2h 32min', '2h 49min', '2h 27min', '2h 20min', '2h 13min', '2h 52min', '2h 46min', '2h 48min', '2h 15min', '2h 1min', '1h 54min', '1h 39min', '2h 35min', '2h 20min', '1h 57min', '1h 41min', '2h 27min', '2h 8min', '2h 26min', '3h 0min', '2h 48min', '1h 52min', '2h 28min', '2h 38min', '1h 59min', '2h 14min', '2h 23min', '2h 2min', '1h 45min', '2h 55min', '2h 33min', '1h 49min', '1h 54min', '2h 28min', '2h 5min', '2h 18min', '2h 22min', '2h 35min', '2h 20min', '2h 37min', '2h 32min', '2h 4min', '2h 19min', '1h 47min', '2h 55min', '2h 35min', '2h 26min', '1h 45min', '2h 24min', '2h 44min', '1h 57min', '2h 38min', '2h 46min', '2h 45min', '2h 23min', '2h 5min', '2h 11min', '2h 0min']

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Initializing a dictionary to store age criteria for each movie URL
age_criteria = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for age_rating in case it's not found
    age_rating = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Age Rating'
        if subheading and 'Age rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            age_rating_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the age_rating_div is found
            if age_rating_div:
                # Extracting the age rating value
                age_rating = age_rating_div.text.strip()

    # Storing the age rating value in the dictionary with the movie URL as the key
    age_criteria[url] =age_rating

# Print the dictionary containing age_rating_value values for each movie URL
print(age_criteria)
# Out:
# {'https://www.justwatch.com/in/movie/animal-2022': 'A', 'https://www.justwatch.com/in/movie/12th-fail': 'NA', 'https://www.justwatch.com/in/movie/salaar': 'A', 'https://www.justwatch.com/in/movie/sam-bahadur': 'UA', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'NA', 'https://www.justwatch.com/in/movie/tiger-3': 'NA', 'https://www.justwatch.com/in/movie/nani30': 'U', 'https://www.justwatch.com/in/movie/oppenheimer': 'UA', 'https://www.justwatch.com/in/movie/hanu-man': 'UA', 'https://www.justwatch.com/in/movie/mission-impossible-7': 'NA', 'https://www.justwatch.com/in/movie/dunki': 'NA', 'https://www.justwatch.com/in/movie/killers-of-the-flower-moon': 'A', 'https://www.justwatch.com/in/movie/parking-2023': 'UA', 'https://www.justwatch.com/in/movie/devil-2023': 'NA', 'https://www.justwatch.com/in/movie/jawan': 'UA', 'https://www.justwatch.com/in/movie/sapta-sagaradaache-ello-side-b': 'UA', 'https://www.justwatch.com/in/movie/the-kerala-story': 'A', 'https://www.justwatch.com/in/movie/guthlee-ladoo': 'NA', 'https://www.justwatch.com/in/movie/neru': 'UA', 'https://www.justwatch.com/in/movie/barbie-2023': 'UA', 'https://www.justwatch.com/in/movie/society-of-the-snow': 'NA', 'https://www.justwatch.com/in/movie/lift-0': 'NA', 'https://www.justwatch.com/in/movie/the-marvels': 'NA', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'NA', 'https://www.justwatch.com/in/movie/fighter-2022': 'UA', 'https://www.justwatch.com/in/movie/kaathal-the-core': 'UA', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'NA', 'https://www.justwatch.com/in/movie/anyone-but-you': 'NA', 'https://www.justwatch.com/in/movie/poor-things': 'NA', 'https://www.justwatch.com/in/movie/saltburn': 'NA', 'https://www.justwatch.com/in/movie/ssmb-28': 'UA', 'https://www.justwatch.com/in/movie/migration': 'NA', 'https://www.justwatch.com/in/movie/talk-to-me-2022': 'NA', 'https://www.justwatch.com/in/movie/napoleon-2023': 'NA', 'https://www.justwatch.com/in/movie/mangalavaram': 'NA', 'https://www.justwatch.com/in/movie/past-lives': 'UA', 'https://www.justwatch.com/in/movie/joram': 'UA', 'https://www.justwatch.com/in/movie/leo-2023': 'UA', 'https://www.justwatch.com/in/movie/the-family-plan': 'A', 'https://www.justwatch.com/in/movie/saindhav': 'UA', 'https://www.justwatch.com/in/movie/merry-christmas-2024': 'UA', 'https://www.justwatch.com/in/movie/kho-gaye-hum-kahan': 'NA', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'U', 'https://www.justwatch.com/in/movie/interstellar': 'NA', 'https://www.justwatch.com/in/movie/joe-2023': 'NA', 'https://www.justwatch.com/in/movie/chittha': 'UA', 'https://www.justwatch.com/in/movie/the-holdovers': 'NA', 'https://www.justwatch.com/in/movie/jigarthanda-doublex': 'UA', 'https://www.justwatch.com/in/movie/777-charlie': 'UA', 'https://www.justwatch.com/in/movie/rocky-aur-rani-ki-prem-kahani': 'NA', 'https://www.justwatch.com/in/movie/dada-2023': 'U', 'https://www.justwatch.com/in/movie/mad-max-fury-road': 'A', 'https://www.justwatch.com/in/movie/365-days': 'NA', 'https://www.justwatch.com/in/movie/three-of-us': 'NA', 'https://www.justwatch.com/in/movie/extra': 'NA', 'https://www.justwatch.com/in/movie/zara-hatke-zara-bach-ke': 'UA', 'https://www.justwatch.com/in/movie/wonka': 'U', 'https://www.justwatch.com/in/movie/role-play-2023': 'NA', 'https://www.justwatch.com/in/movie/antony-2023': 'NA', 'https://www.justwatch.com/in/movie/blue-beetle': 'NA', 'https://www.justwatch.com/in/movie/annapoorani': 'UA', 'https://www.justwatch.com/in/movie/the-wolf-of-wall-street': 'A', 'https://www.justwatch.com/in/movie/gadar-2': 'UA', 'https://www.justwatch.com/in/movie/tejas': 'NA', 'https://www.justwatch.com/in/movie/inception': 'UA', 'https://www.justwatch.com/in/movie/pindam': 'UA', 'https://www.justwatch.com/in/movie/starfish-2023': 'A', 'https://www.justwatch.com/in/movie/the-creator': 'NA', 'https://www.justwatch.com/in/movie/aquaman': 'UA', 'https://www.justwatch.com/in/movie/jok ...

# %%
# Create a list comprehension to extract values from the 'age_criteria' dictionary
age_rating = [rating for rating in age_criteria.values()]

# Print the list of age ratings
print(age_rating)
# Out:
# ['A', 'NA', 'A', 'UA', 'NA', 'NA', 'U', 'UA', 'UA', 'NA', 'NA', 'A', 'UA', 'NA', 'UA', 'UA', 'A', 'NA', 'UA', 'UA', 'NA', 'NA', 'NA', 'NA', 'UA', 'UA', 'NA', 'NA', 'NA', 'NA', 'UA', 'NA', 'NA', 'NA', 'NA', 'UA', 'UA', 'UA', 'A', 'UA', 'UA', 'NA', 'U', 'NA', 'NA', 'UA', 'NA', 'UA', 'UA', 'NA', 'U', 'A', 'NA', 'NA', 'NA', 'UA', 'U', 'NA', 'NA', 'NA', 'UA', 'A', 'UA', 'NA', 'UA', 'UA', 'A', 'NA', 'UA', 'A', 'NA', 'UA', 'NA', 'NA', 'UA', 'UA', 'NA', 'UA', 'UA', 'UA', 'NA', 'UA', 'NA', 'UA', 'UA', 'UA', 'UA', 'U', 'NA', 'NA', 'A', 'A', 'UA', 'U', 'UA', 'UA', 'A', 'NA', 'UA', 'NA']

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# Initializing a dictionary to store production_country for each movie URL
production_country = {}

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for production country in case it's not found
    country = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Production country'
        if subheading and 'Production country' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            country_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the country_div is found
            if country_div:
                # Extracting the country name
                country = country_div .text.strip()

    # Storing the country name  in the dictionary with the movie URL as the key
    production_country[url] =country

# Print the dictionary containing counry for each movie URL
print(production_country)
# Out:
# {'https://www.justwatch.com/in/movie/animal-2022': 'India', 'https://www.justwatch.com/in/movie/12th-fail': 'India', 'https://www.justwatch.com/in/movie/salaar': 'India', 'https://www.justwatch.com/in/movie/sam-bahadur': 'India', 'https://www.justwatch.com/in/movie/aquaman-and-the-lost-kingdom': 'United States', 'https://www.justwatch.com/in/movie/tiger-3': 'India', 'https://www.justwatch.com/in/movie/nani30': 'India', 'https://www.justwatch.com/in/movie/oppenheimer': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/hanu-man': 'India', 'https://www.justwatch.com/in/movie/mission-impossible-7': 'United States', 'https://www.justwatch.com/in/movie/dunki': 'India', 'https://www.justwatch.com/in/movie/killers-of-the-flower-moon': 'United States', 'https://www.justwatch.com/in/movie/parking-2023': 'India', 'https://www.justwatch.com/in/movie/devil-2023': 'India', 'https://www.justwatch.com/in/movie/jawan': 'India', 'https://www.justwatch.com/in/movie/sapta-sagaradaache-ello-side-b': 'India', 'https://www.justwatch.com/in/movie/the-kerala-story': 'India', 'https://www.justwatch.com/in/movie/guthlee-ladoo': 'India', 'https://www.justwatch.com/in/movie/neru': 'India', 'https://www.justwatch.com/in/movie/barbie-2023': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/society-of-the-snow': 'Spain, United States', 'https://www.justwatch.com/in/movie/lift-0': 'United States', 'https://www.justwatch.com/in/movie/the-marvels': 'United States', 'https://www.justwatch.com/in/movie/anatomie-dune-chute': 'France', 'https://www.justwatch.com/in/movie/fighter-2022': 'India', 'https://www.justwatch.com/in/movie/kaathal-the-core': 'India', 'https://www.justwatch.com/in/movie/the-beekeeper-2024': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/anyone-but-you': 'United States, Australia', 'https://www.justwatch.com/in/movie/poor-things': 'United Kingdom, United States, Ireland', 'https://www.justwatch.com/in/movie/saltburn': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/ssmb-28': 'India', 'https://www.justwatch.com/in/movie/migration': 'Canada, France, United States', 'https://www.justwatch.com/in/movie/talk-to-me-2022': 'United Kingdom, Australia', 'https://www.justwatch.com/in/movie/napoleon-2023': 'United States, United Kingdom', 'https://www.justwatch.com/in/movie/mangalavaram': 'India', 'https://www.justwatch.com/in/movie/past-lives': 'South Korea, United States', 'https://www.justwatch.com/in/movie/joram': 'India', 'https://www.justwatch.com/in/movie/leo-2023': 'India', 'https://www.justwatch.com/in/movie/the-family-plan': 'United States', 'https://www.justwatch.com/in/movie/saindhav': 'India', 'https://www.justwatch.com/in/movie/merry-christmas-2024': 'India', 'https://www.justwatch.com/in/movie/kho-gaye-hum-kahan': 'India', 'https://www.justwatch.com/in/movie/harry-potter-and-the-philosophers-stone': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/interstellar': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/joe-2023': 'India', 'https://www.justwatch.com/in/movie/chittha': 'India', 'https://www.justwatch.com/in/movie/the-holdovers': 'United States', 'https://www.justwatch.com/in/movie/jigarthanda-doublex': 'India', 'https://www.justwatch.com/in/movie/777-charlie': 'India', 'https://www.justwatch.com/in/movie/rocky-aur-rani-ki-prem-kahani': 'India', 'https://www.justwatch.com/in/movie/dada-2023': 'India', 'https://www.justwatch.com/in/movie/mad-max-fury-road': 'Australia, United States', 'https://www.justwatch.com/in/movie/365-days': 'Poland', 'https://www.justwatch.com/in/movie/three-of-us': 'India', 'https://www.justwatch.com/in/movie/extra': 'India', 'https://www.justwatch.com/in/movie/zara-hatke-zara-bach-ke': 'India', 'https://www.justwatch.com/in/movie/wonka': 'United Kingdom, United States', 'https://www.justwatch.com/in/movie/role-play-2023': 'United States, France, Germany', 'https://www.justwatch.com/in/movie/ ...

# %%
# Create a list comprehension to extract values from the production country dictionary
Production_country=[country for country in production_country.values()]
# Print the list of Production country
print(Production_country)
# Out:
# ['India', 'India', 'India', 'India', 'United States', 'India', 'India', 'United Kingdom, United States', 'India', 'United States', 'India', 'United States', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'United Kingdom, United States', 'Spain, United States', 'United States', 'United States', 'France', 'India', 'India', 'United Kingdom, United States', 'United States, Australia', 'United Kingdom, United States, Ireland', 'United Kingdom, United States', 'India', 'Canada, France, United States', 'United Kingdom, Australia', 'United States, United Kingdom', 'India', 'South Korea, United States', 'India', 'India', 'United States', 'India', 'India', 'India', 'United Kingdom, United States', 'United Kingdom, United States', 'India', 'India', 'United States', 'India', 'India', 'India', 'India', 'Australia, United States', 'Poland', 'India', 'India', 'India', 'United Kingdom, United States', 'United States, France, Germany', 'India', 'United States', 'India', 'United States', 'India', 'India', 'United Kingdom, United States', 'India', 'India', 'Canada, United States', 'United States', 'Canada, United States', 'United States', 'United States', 'India', 'South Korea', 'India', 'India', 'Japan', 'India', 'United States', 'United States', 'United States, United Kingdom', 'India', 'United States, United Kingdom', 'India', 'India', 'France, Netherlands, United Kingdom, United States', 'India', 'India', 'United States, India', 'United States, Poland, United Kingdom', 'United States', 'United States, Canada, United Kingdom', 'United States', 'India', 'India', 'India', 'United States, Germany', 'India', 'United States', 'United Kingdom']

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Initializing an empty list to store streaming platform names
streaming_platform = []

# Iterating through each movie URL
for url in movie_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the img element with class 'offer__icon'
    platform = soup.find('img', class_='offer__icon')

    # Checking if the platform element is found
    if platform:
        # Extracting the 'alt' attribute, which contains the platform name
        platform_name = platform['alt']
    else:
        # Setting platform_name to 'NA' if the platform element is not found
        platform_name = "NA"

    # Handling the specific case where the platform_name is 'Bookmyshow'
    # Appending 'NA' to the list in this case
    if platform_name == 'Bookmyshow':
        streaming_platform.append('NA')
    else:
        # Appending the platform_name to the list
        streaming_platform.append(platform_name)

# Print the list of streaming platform names
print(streaming_platform)
# Out:
# ['Netflix', 'Hotstar', 'Netflix', 'Zee5', 'Apple TV', 'Amazon Prime Video', 'Netflix', 'Apple TV', 'NA', 'Apple TV', 'NA', 'Apple TV Plus', 'NA', 'Amazon Prime Video', 'Apple TV', 'Amazon Prime Video', 'NA', 'Amazon Prime Video', 'Hotstar', 'Apple TV', 'Netflix', 'Netflix', 'Apple TV', 'NA', 'NA', 'Amazon Prime Video', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Apple TV', 'Apple TV', 'NA', 'Lionsgate Play', 'Amazon Video', 'Netflix', 'Apple TV Plus', 'Amazon Prime Video', 'NA', 'Netflix', 'Apple TV', 'Apple TV', 'NA', 'Hotstar', 'NA', 'Netflix', 'Voot', 'Amazon Prime Video', 'Amazon Prime Video', 'Apple TV', 'Netflix', 'Netflix', 'NA', 'NA', 'Apple TV', 'Amazon Prime Video', 'Amazon Prime Video', 'Apple TV', 'NA', 'Lionsgate Play', 'Zee5', 'NA', 'Apple TV', 'Amazon Prime Video', 'Netflix', 'Apple TV', 'Apple TV', 'Apple TV', 'Apple TV', 'Apple TV', 'Sony Liv', 'Netflix', 'Amazon Prime Video', 'NA', 'NA', 'Zee5', 'Apple TV', 'Apple TV', 'Apple TV', 'NA', 'Apple TV', 'Amazon Prime Video', 'Apple TV', 'Apple TV', 'Amazon Prime Video', 'NA', 'Apple TV', 'NA', 'Apple TV', 'Apple TV', 'Apple TV', 'Sony Liv', 'Amazon Prime Video', 'Netflix', 'Apple TV', 'NA', 'Apple TV', 'Hotstar']

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Creating a dictionary with keys as column names and values as lists
movie_data = {
                'Title': movie_title,
                'Release_year': release_year,
                'Genre': movie_genres,
                'IMDB_Rating': imdb_ratings,
                'Age_rating': age_rating,
                'Duration': duration,
                'Production_country': Production_country,
                'Streaming_service': streaming_platform,
                'URL': movie_urls
              }

# Creating a DataFrame using the dictionary
movie_df = pd.DataFrame(movie_data)

# %%
#head of dataframe
movie_df.head(10)
# Out:
#                           Title Release_year  \
# 0                   animal-2022         2023
# 1                     12th-fail         2023
# 2                        salaar         2023
# 3                   sam-bahadur         2023
# 4  aquaman-and-the-lost-kingdom         2023
# 5                       tiger-3         2023
# 6                        nani30         2023
# 7                   oppenheimer         2023
# 8                      hanu-man         2024
# 9          mission-impossible-7         2023
#
#                                                Genre IMDB_Rating Age_rating  \
# 0  Action & Adventure, Drama, Crime, Mystery & Th...         6.4          A
# 1                                              Drama         9.2         NA
# 2  Action & Adventure, Crime, Drama, Mystery & Th...         6.6          A
# 3                     War & Military, Drama, History         7.9         UA
# 4       Action & Adventure, Fantasy, Science-Fiction         5.7         NA
# 5             Action & Adventure, Mystery & Thriller         6.0         NA
# 6                      Drama, Kids & Family, Romance         8.3          U
# 7                                     Drama, History         8.4         UA
# 8  Fantasy, Action & Adventure, Comedy, Science-F...         8.5         UA
# 9             Action & Adventure, Mystery & Thriller         7.7         NA
#
#    Duration             Production_country   Streaming_service  \
# 0  3h 21min                          India             Netflix
# 1  2h 26min                          India             Hotstar
# 2  2h 55min                          India             Netflix
# 3  2h 30min                          India                Zee5
# 4   2h 4min                  United States            Apple TV
# 5  2h 35min                          India  Amazon Prime Video
# 6  2h 35min                          India             Netflix
# 7   3h 1min  United Kingdom, United States            Apple TV
# 8  2h 39min                          India                  NA
# 9  2h 44min                  United States            Apple TV
#
#                                                  URL
# 0     https://www.justwatch.com/in/movie/animal-2022
# 1       https://www.justwatch.com/in/movie/12th-fail
# 2          https://www.justwatch.com/in/movie/salaar
# 3     https://www.justwatch.com/in/movie/sam-bahadur
# 4  https://www.justwatch.com/in/movie/aquaman-and...
# 5         https://www.justwatch.com/in/movie/tiger-3
# 6          https://www.justwatch.com/in/movie/nani30
# 7     https://www.justwatch.com/in/movie/oppenheimer
# 8        https://www.justwatch.com/in/movie/hanu-man
# 9  https://www.justwatch.com/in/movie/mission-imp...

# %%
# Adding a new column 'Type' to the DataFrame with constant value 'Movie'
movie_df['Type'] = 'Movie'

# %%
#head of dataframe
movie_df.head()
# Out:
#                           Title Release_year  \
# 0                   animal-2022         2023
# 1                     12th-fail         2023
# 2                        salaar         2023
# 3                   sam-bahadur         2023
# 4  aquaman-and-the-lost-kingdom         2023
#
#                                                Genre IMDB_Rating Age_rating  \
# 0  Action & Adventure, Drama, Crime, Mystery & Th...         6.4          A
# 1                                              Drama         9.2         NA
# 2  Action & Adventure, Crime, Drama, Mystery & Th...         6.6          A
# 3                     War & Military, Drama, History         7.9         UA
# 4       Action & Adventure, Fantasy, Science-Fiction         5.7         NA
#
#    Duration Production_country Streaming_service  \
# 0  3h 21min              India           Netflix
# 1  2h 26min              India           Hotstar
# 2  2h 55min              India           Netflix
# 3  2h 30min              India              Zee5
# 4   2h 4min      United States          Apple TV
#
#                                                  URL   Type
# 0     https://www.justwatch.com/in/movie/animal-2022  Movie
# 1       https://www.justwatch.com/in/movie/12th-fail  Movie
# 2          https://www.justwatch.com/in/movie/salaar  Movie
# 3     https://www.justwatch.com/in/movie/sam-bahadur  Movie
# 4  https://www.justwatch.com/in/movie/aquaman-and...  Movie

# %%
#shape of data
movie_df.shape
# Out:
# (100, 10)

# %%
#shape of data
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               100 non-null    object
#  1   Release_year        100 non-null    object
#  2   Genre               100 non-null    object
#  3   IMDB_Rating         100 non-null    object
#  4   Age_rating          100 non-null    object
#  5   Duration            100 non-null    object
#  6   Production_country  100 non-null    object
#  7   Streaming_service   100 non-null    object
#  8   URL                 100 non-null    object
#  9   Type                100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB

# %%
#converting release year to date format
movie_df['Release_year'] = pd.to_datetime(movie_df['Release_year'], format='%Y').dt.year

# %%
movie_df.head(2)
# Out:
#          Title Release_year  \
# 0  animal-2022         2023
# 1    12th-fail         2023
#
#                                                Genre IMDB_Rating Age_rating  \
# 0  Action & Adventure, Drama, Crime, Mystery & Th...         6.4          A
# 1                                              Drama         9.2         NA
#
#    Duration Production_country Streaming_service  \
# 0  3h 21min              India           Netflix
# 1  2h 26min              India           Hotstar
#
#                                               URL   Type
# 0  https://www.justwatch.com/in/movie/animal-2022  Movie
# 1    https://www.justwatch.com/in/movie/12th-fail  Movie

# %%
movie_df = movie_df.replace(r'^\s*$', np.nan, regex=True)

# %%
# Replace 'NA' with NaN (Not a Number)
movie_df['IMDB_Rating'].replace('NA', float('nan'), inplace=True)

# Convert the 'IMDB_Rating' column to float
movie_df['IMDB_Rating'] = movie_df['IMDB_Rating'].astype(float)
movie_df['Release_year'] = movie_df['Release_year'].astype(float)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               100 non-null    object
#  1   Release_year        100 non-null    float64
#  2   Genre               100 non-null    object
#  3   IMDB_Rating         98 non-null     float64
#  4   Age_rating          100 non-null    object
#  5   Duration            100 non-null    object
#  6   Production_country  100 non-null    object
#  7   Streaming_service   100 non-null    object
#  8   URL                 100 non-null    object
#  9   Type                100 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 7.9+ KB

# %% [markdown]
# ### **Done With scraping Movie Data, Now let's Scrape Tv Show related Data**

# %% [markdown]
# #Scraping TV Show Data

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL
page=requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
#   <meta content="302" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/>
#   <meta content="yes" data-vue-meta="ssr" name="mobile-web-app-capable"/>
#   <meta content="yes" data-vue-meta="ssr" name="apple-mobile-web-app-capable"/>
#   <meta content="#182531" data-vue-meta="ssr" name="theme-color"/>
#   <meta content="4eBTNBm4L6RaWdF8V51EHZajskAMgXYAg81iRXJqumQ" data-vue-meta="ssr" name="google-site-verification"/>
#   <meta content="d61y4roe8t5xwbb0gfu6gwe8j8iq3i" data-vue-meta="ssr" name="facebook-domain-verification"/>
#   <meta content="dmorpwc4h544ct6mv" data-vue-meta="ssr" name="dailymotion-domain-verification"/>
#   <meta content="Watch series online" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/>
#   <meta content="watch series, watch tv series online, series online, online watch tv shows online, best shows to binge watch, popular tv shows" data-vue-meta="ssr" name="keywords"/>
#   <meta content="Where to watch TV series online? Find with JustWatch all the series you can stream online on Netflix, Hooq, Voot and 10 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="description" data-vue-meta="ssr" name="description"/>
#   <meta content="Where to watch TV series online? Find with JustWatch all the series you can stream online on Netflix, Hooq, Voot and 10 other streaming providers. Purchase, rent online &amp; flat-rate." data-vmid="og:description" data-vue-meta="ssr" property="og:description"/>
#   <meta content="noindex, follow" data-vmid="robots" data-vue-meta="ssr" name="robots"/>
#   <title>
#    Watch series online
#   </title>
#   <link data-vue-meta="ssr" href="https://app.usercentrics.eu" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://graphql.usercentrics.eu" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://api.usercentrics.eu" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://consents.usercentrics.eu" rel="dns-prefetch"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-700.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-900.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/anton.woff" rel="preload" type="font/woff2"/>
#   <link data-vue-meta="ssr" href="/appassets/favicon.ico" rel="icon"/>
#   <link crossorigin="use-credentials" data-vue-meta="ssr" href="https://images.justwatch.com" rel="preconnect"/>
#   <link data-vue-meta="ssr" href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
#   <link data-vue-meta="ssr" href="https://ib.adnxs.com" rel="dns-prefetch"/>
#   <link data-vmid="canonical" data-vue-meta="ssr" href="https://www.justwatch.com/in/tv-shows" rel="canonical"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ad/series" hreflang="ca-AD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ae/tv-shows" hreflang="ar-AE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ag/tv-shows" hreflang="en-AG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/al/seriale-televizive" hreflang="sq-AL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ao/series" hreflang="pt-AO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ar/series" hreflang="es-AR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/at/Serien" hreflang="de-AT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/au/tv-shows" hreflang="en-AU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/az/televiziya-şouları" hreflang="az-AZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ba/tv-serije" hreflang="bs-BA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bb/tv-shows" hreflang="en-BB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/be/series" hreflang="fr-BE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bf/series" hreflang="fr-BF" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bg/сериали" hreflang="bg-BG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bh/tv-shows" hreflang="ar-BH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bm/tv-shows" hreflang="en-BM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bo/series" hreflang="es-BO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/br/series" hreflang="pt-BR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bs/tv-shows" hreflang="en-BS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/by/сезон" hreflang="be-BY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/bz/tv-shows" hreflang="en-BZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ca/tv-shows" hreflang="en-CA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cd/series" hreflang="fr-CD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ch/Serien" hreflang="de-CH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ci/series" hreflang="fr-CI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cl/series" hreflang="es-CL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cm/tv-shows" hreflang="en-CM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/co/series" hreflang="es-CO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cr/series" hreflang="es-CR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cu/sericu" hreflang="es-CU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cv/series" hreflang="pt-CV" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cy/τηλεοπτικές-σειρές" hreflang="el-CY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/cz/serialy" hreflang="cs-CZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/de/Serien" hreflang="de-DE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dk/tv-series" hreflang="en-DK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/do/serido" hreflang="es-DO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/dz/tv-shows" hreflang="ar-DZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ec/series" hreflang="es-EC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/eg/tv-shows" hreflang="ar-EG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/es/series" hreflang="es-ES" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fi/sarjat" hreflang="fi-FI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fj/tv-shows" hreflang="en-FJ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/fr/series" hreflang="fr-FR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uk/tv-series" hreflang="en-GB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gf/series" hreflang="fr-GF" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gg/tv-shows" hreflang="en-GG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gh/tv-shows" hreflang="en-GH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gi/tv-shows" hreflang="en-GI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gq/serigq" hreflang="es-GQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gr/τηλεοπτικές-σειρές" hreflang="el-GR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gt/series" hreflang="es-GT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/gy/tv-shows" hreflang="en-GY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hk/電視節目" hreflang="zh-HK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hn/series" hreflang="es-HN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hr/serije" hreflang="hr-HR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/hu/tv-sorozat" hreflang="hu-HU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ie/tv-series" hreflang="en-IE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/il/tv-shows" hreflang="he-IL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/in/tv-shows" hreflang="en-IN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/iq/tv-shows" hreflang="ar-IQ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/is/þættir" hreflang="is-IS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/it/serie-tv" hreflang="it-IT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jm/tv-shows" hreflang="en-JM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jo/tv-shows" hreflang="ar-JO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/jp/テレビ番組" hreflang="ja-JP" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ke/tv-shows" hreflang="en-KE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kr/TV-프로그램" hreflang="ko-KR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/kw/tv-shows" hreflang="ar-KW" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lb/tv-shows" hreflang="ar-LB" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lc/tv-shows" hreflang="en-LC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/li/Serien" hreflang="de-LI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lu/series" hreflang="fr-LU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ly/tv-shows" hreflang="ar-LY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ma/tv-shows" hreflang="ar-MA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mc/series" hreflang="fr-MC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/md/seriale" hreflang="ro-MD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/me/tv-programi" hreflang="sr-ME" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mg/series" hreflang="fr-MG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mk/тв-серии" hreflang="mk-MK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ml/series" hreflang="fr-ML" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mt/serje-televiżivi" hreflang="mt-MT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mu/series" hreflang="fr-MU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mw/tv-shows" hreflang="en-MW" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mx/series" hreflang="es-MX" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/my/tv-shows" hreflang="en-MY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/mz/series" hreflang="pt-MZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ne/series" hreflang="fr-NE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ng/tv-shows" hreflang="en-NG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ni/serini" hreflang="es-NI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nl/tv-series" hreflang="en-NL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/no/tv-series" hreflang="en-NO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/nz/tv-shows" hreflang="en-NZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/om/tv-shows" hreflang="ar-OM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pa/seripa" hreflang="es-PA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pe/series" hreflang="es-PE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pf/series" hreflang="fr-PF" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pg/tv-shows" hreflang="en-PG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ph/tv-shows" hreflang="en-PH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pk/tv-shows" hreflang="ur-PK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pl/seriale" hreflang="pl-PL" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ps/tv-shows" hreflang="ar-PS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/pt/series" hreflang="pt-PT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/py/series" hreflang="es-PY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/qa/tv-shows" hreflang="ar-QA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ro/seriale" hreflang="ro-RO" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/rs/tv-programi" hreflang="sr-RS" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ru/сериалы" hreflang="ru-RU" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sa/tv-shows" hreflang="ar-SA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sc/series" hreflang="fr-SC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/se/tv-serier" hreflang="sv-SE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sg/tv-shows" hreflang="en-SG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/si/serije" hreflang="sl-SI" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sk/seriály" hreflang="sk-SK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sm/serie-tv" hreflang="it-SM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sn/series" hreflang="fr-SN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/sv/serisv" hreflang="es-SV" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tc/tv-shows" hreflang="en-TC" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/td/tv-shows" hreflang="ar-TD" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tn/tv-shows" hreflang="ar-TN" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tr/tv-dizileri" hreflang="tr-TR" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tt/tv-shows" hreflang="en-TT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tz/maonyesho-ya-tv" hreflang="sw-TZ" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ua/телесеріали" hreflang="uk-UA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ug/tv-shows" hreflang="en-UG" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/us/tv-shows" hreflang="en-US" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/uy/seriuy" hreflang="es-UY" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/va/serie-tv" hreflang="it-VA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ve/series" hreflang="es-VE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/xk/seriale-televizive" hreflang="sq-XK" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ye/tv-shows" hreflang="ar-YE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/za/tv-series" hreflang="en-ZA" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/zm/tv-shows" hreflang="en-ZM" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/zw/tv-shows" hreflang="en-ZW" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/ee/seriaalid" hreflang="et-EE" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lv/tv-pārraide" hreflang="lv-LV" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/lt/tv-laidos" hreflang="lt-LT" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/id/tv-shows" hreflang="en-ID" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/th/tv-shows" hreflang="en-TH" rel="alternate"/>
#   <link data-vue-meta="ssr" href="https://www.justwatch.com/tw/電視節目" hreflang="zh-TW" rel="alternate"/>
#   <base href="/" target="_self"/>
#   <link as="image" href="/appassets/img/logo/JustWatch-logo-large.webp" imagesrcset="/appassets/img/logo/JustWatch-logo-large.webp 1px" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/207360008/s100/netflix.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/52449861/s100/amazonprimevideo.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/152862153/s100/appletvplus.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/190848813/s100/itunes.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/127445869/s100/crunchyroll.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/240029443/s100/hotstar.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/icon/4233119/s100/voot.{format}/icon.webp" imagesrcset="https://www.justwatch.com/images/icon/4233119/s100/voot.{format}/icon.webp 1px" importance="high" media="(min-width: 0px)" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/256745585/s166/jack-reacher.webp" imagesrcset="https://www.justwatch.com/images/poster/256745585/s166/jack-reacher.webp 1px, https://www.justwatch.com/images/poster/256745585/s166/jack-reacher.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/181793751/s166/true-detective.webp" imagesrcset="https://www.justwatch.com/images/poster/181793751/s166/true-detective.webp 1px, https://www.justwatch.com/images/poster/181793751/s166/true-detective.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/310545062/s166/indian-police-force.webp" imagesrcset="https://www.justwatch.com/images/poster/310545062/s166/indian-police-force.webp 1px, https://www.justwatch.com/images/poster/310545062/s166/indian-police-force.webp" importance="high" rel="preload"/>
#   <link as="image" href="https://www.justwatch.com/images/poster/98979565/s166/mirzapur.webp" imagesrcset="https://www.justwatch.com/images/poster/98979565/s166/mirzapur.webp 1px, https://www.justwatch.com/images/poster/98979565/s166/mirzapur.webp" importance="high" rel="preload"/>
#   <style data-vue-ssr-id="16dee5de:0 16dee5de:1 374c0f88:0 4d630dd0:0 290963e8:0 30404f7e:0 2c4532b4:0 4dfbcd23:0 f084ba36:0 ea4d06ee:0 6dcc8ee6:0 244ddff4:0 69fd216c:0 08ddf3ea:0 10155196:0 0205dd46:0 26e8eb5f:0 71268dee:0 04f1c005:0 6de04a75:0 6240279c:0 72101108:0 40c85688:0 6d26d0c3:0 754b4d6b:0 d9ba2922:0 588ea6ac:0 c5a4a028:0 03e9b512:0 15d0a34a:0 44770f63:0 3cf28c3e:0 28bf261c:0 0de9810f:0 72740b88:0 493a7b4c:0">
#    html.ios{--ion-default-font:-apple-system,BlinkMacSystemFont,"Helvetica Neue","Roboto",sans-serif}html.md{--ion-default-font:"Roboto","Helvetica Neue",sans-serif}html{--ion-font-family:var(--ion-default-font)}body{background:var(--ion-background-color)}body.backdrop-no-scroll{overflow:hidden}html.ios ion-modal.modal-card .ion-page>ion-header>ion-toolbar:first-of-type{padding-top:0}html.ios ion-modal .ion-page{border-radius:inherit}.ion-color-primary{--ion-color-base:var(--ion-color-primary,#3880ff)!important;--ion-color-base-rgb:var(--ion-color-primary-rgb,56,128,255)!important;--ion-color-contrast:var(--ion-color-primary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-primary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-primary-shade,#3171e0)!important;--ion-color-tint:var(--ion-color-primary-tint,#4c8dff)!important}.ion-color-secondary{--ion-color-base:var(--ion-color-secondary,#3dc2ff)!important;--ion-color-base-rgb:var(--ion-color-secondary-rgb,61,194,255)!important;--ion-color-contrast:var(--ion-color-secondary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-secondary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-secondary-shade,#36abe0)!important;--ion-color-tint:var(--ion-color-secondary-tint,#50c8ff)!important}.ion-color-tertiary{--ion-color-base:var(--ion-color-tertiary,#5260ff)!important;--ion-color-base-rgb:var(--ion-color-tertiary-rgb,82,96,255)!important;--ion-color-contrast:var(--ion-color-tertiary-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-tertiary-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-tertiary-shade,#4854e0)!important;--ion-color-tint:var(--ion-color-tertiary-tint,#6370ff)!important}.ion-color-success{--ion-color-base:var(--ion-color-success,#2dd36f)!important;--ion-color-base-rgb:var(--ion-color-success-rgb,45,211,111)!important;--ion-color-contrast:var(--ion-color-success-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-success-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-success-shade,#28ba62)!important;--ion-color-tint:var(--ion-color-success-tint,#42d77d)!important}.ion-color-warning{--ion-color-base:var(--ion-color-warning,#ffc409)!important;--ion-color-base-rgb:var(--ion-color-warning-rgb,255,196,9)!important;--ion-color-contrast:var(--ion-color-warning-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-warning-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-warning-shade,#e0ac08)!important;--ion-color-tint:var(--ion-color-warning-tint,#ffca22)!important}.ion-color-danger{--ion-color-base:var(--ion-color-danger,#eb445a)!important;--ion-color-base-rgb:var(--ion-color-danger-rgb,235,68,90)!important;--ion-color-contrast:var(--ion-color-danger-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-danger-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-danger-shade,#cf3c4f)!important;--ion-color-tint:var(--ion-color-danger-tint,#ed576b)!important}.ion-color-light{--ion-color-base:var(--ion-color-light,#f4f5f8)!important;--ion-color-base-rgb:var(--ion-color-light-rgb,244,245,248)!important;--ion-color-contrast:var(--ion-color-light-contrast,#000)!important;--ion-color-contrast-rgb:var(--ion-color-light-contrast-rgb,0,0,0)!important;--ion-color-shade:var(--ion-color-light-shade,#d7d8da)!important;--ion-color-tint:var(--ion-color-light-tint,#f5f6f9)!important}.ion-color-medium{--ion-color-base:var(--ion-color-medium,#92949c)!important;--ion-color-base-rgb:var(--ion-color-medium-rgb,146,148,156)!important;--ion-color-contrast:var(--ion-color-medium-contrast,#fff)!important;--ion-color-contrast-rgb:var(--ion-color-medium-contrast-rgb,255,255,255)!important;--ion-color-shade:var(--ion-color-medium-shade,#808289)!important;--ion-color-tint:var(--ion-color-medium-tint,#9d9fa6)!important}.ion-color-dark{--ion-color-base:var(--ion-color-dark,#222428)!important;--ion-color-b ...
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:transparent!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:" (" attr(href) ")"}abbr[title]:after{content:" (" attr(title) ")"}a[href^="#"]:after,a[href^="javascript:"]:after{content:""}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn>.caret,.dropup>.btn>.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{font-family:Lato,Lato-fallback,Arial,sans-serif;font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#428bca}a,a:focus,a:hover{text-decoration:none}a:focus,a:hover{color:#2a6496}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container:after,.container:before{display:table;content:" "}.container:after{clear:both}@media(min-width:768px){.container{width:750px}}@media(min-width:992px){.container{width:970px}}@media(min-width:1200px){.container{width:1170px}}.container-fluid{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before{display:table;content:" "}.container-fluid:after{clear:both}.row{margin-right:-15px;margin-left:-15px}.row:after,.row:before{display:table;content:" "}.row:after{clear:both}.row-no-gutters{margin-right:0;margin-left:0}.row-no-gutters [class*=col-]{padding-right:0;padding-left:0}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{position:relative;min-height:1px;padding-right:15px;padding-left:15px}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{width:50%}.col-xs-7{width:58.3333333333%}.col-xs-8{width:66.6666666667%}.col-xs-9{width:75%}.col-xs-10{width:83.3333333333%}.col-xs-11{width:91.6666666667%}.col-xs-12{width:100%}.col-xs-pull-0{right:auto}.col-xs-pull-1{right:8.3333333333%}.col-xs-pull-2{right:16.6666666667%}.col-xs-pull-3{right:25%}.col-xs-pull-4{right:33.3333333333%}.col-xs-pull-5{right ...
# :host,:root{--fa-font-solid:normal 900 1em/1 "Font Awesome 6 Solid";--fa-font-regular:normal 400 1em/1 "Font Awesome 6 Regular";--fa-font-light:normal 300 1em/1 "Font Awesome 6 Light";--fa-font-thin:normal 100 1em/1 "Font Awesome 6 Thin";--fa-font-duotone:normal 900 1em/1 "Font Awesome 6 Duotone";--fa-font-sharp-solid:normal 900 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-regular:normal 400 1em/1 "Font Awesome 6 Sharp";--fa-font-sharp-light:normal 300 1em/1 "Font Awesome 6 Sharp";--fa-font-brands:normal 400 1em/1 "Font Awesome 6 Brands"}svg:not(:host).svg-inline--fa,svg:not(:root).svg-inline--fa{overflow:visible;box-sizing:content-box}.svg-inline--fa{display:var(--fa-display,inline-block);height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-2xs{vertical-align:.1em}.svg-inline--fa.fa-xs{vertical-align:0}.svg-inline--fa.fa-sm{vertical-align:-.07143em}.svg-inline--fa.fa-lg{vertical-align:-.2em}.svg-inline--fa.fa-xl{vertical-align:-.25em}.svg-inline--fa.fa-2xl{vertical-align:-.3125em}.svg-inline--fa.fa-pull-left{margin-right:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-pull-right{margin-left:var(--fa-pull-margin,.3em);width:auto}.svg-inline--fa.fa-li{width:var(--fa-li-width,2em);top:.25em}.svg-inline--fa.fa-fw{width:var(--fa-fw-width,1.25em)}.fa-layers svg.svg-inline--fa{bottom:0;left:0;margin:auto;position:absolute;right:0;top:0}.fa-layers-counter,.fa-layers-text{display:inline-block;position:absolute;text-align:center}.fa-layers{display:inline-block;height:1em;position:relative;text-align:center;vertical-align:-.125em;width:1em}.fa-layers svg.svg-inline--fa{transform-origin:center center}.fa-layers-text{left:50%;top:50%;transform:translate(-50%,-50%);transform-origin:center center}.fa-layers-counter{background-color:var(--fa-counter-background-color,#ff253a);border-radius:var(--fa-counter-border-radius,1em);box-sizing:border-box;color:var(--fa-inverse,#fff);line-height:var(--fa-counter-line-height,1);max-width:var(--fa-counter-max-width,5em);min-width:var(--fa-counter-min-width,1.5em);overflow:hidden;padding:var(--fa-counter-padding,.25em .5em);right:var(--fa-right,0);text-overflow:ellipsis;top:var(--fa-top,0);transform:scale(var(--fa-counter-scale,.25));transform-origin:top right}.fa-layers-bottom-right{bottom:var(--fa-bottom,0);right:var(--fa-right,0);top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom right}.fa-layers-bottom-left{bottom:var(--fa-bottom,0);left:var(--fa-left,0);right:auto;top:auto;transform:scale(var(--fa-layers-scale,.25));transform-origin:bottom left}.fa-layers-top-right{top:var(--fa-top,0);right:var(--fa-right,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top right}.fa-layers-top-left{left:var(--fa-left,0);right:auto;top:var(--fa-top,0);transform:scale(var(--fa-layers-scale,.25));transform-origin:top left}.fa-1x{font-size:1em}.fa-2x{font-size:2em}.fa-3x{font-size:3em}.fa-4x{font-size:4em}.fa-5x{font-size:5em}.fa-6x{font-size:6em}.fa-7x{font-size:7em}.fa-8x{font-size:8em}.fa-9x{font-size:9em}.fa-10x{font-size:10em}.fa-2xs{font-size:.625em;line-height:.1em;vertical-align:.225em}.fa-xs{font-size:.75em;line-height:.08333em;vertical-align:.125em}.fa-sm{font-size:.875em;line-height:.07143em;vertical-align:.05357em}.fa-lg{font-size:1.25em;line-height:.05em;vertical-align:-.075em}.fa-xl{font-size:1.5em;line-height:.04167em;vertical-align:-.125em}.fa-2xl{font-size:2em;line-height:.03125em;vertical-align:-.1875em}.fa-fw{text-align:center;width:1.25em}.fa-ul{list-style-type:none;margin-left:var(--fa-li-margin,2.5em);padding-left:0}.fa-ul>li{position:relative}.fa-li{left:calc(var(--fa-li-width, 2em)*-1);position:absolute;text-align:center;width:var(--fa-li-width,2em);line-height:inherit}.fa-border{border-radius:var(--fa-border-radius,.1em);border:var(--fa-border-width,.08em) var(--fa-border-style,solid) var(--fa-border-color,#eee);padding:var(--fa-border-padding,.2em .25em .15em)}.fa-pull-left{float:left;margin-right:var(--fa-pull-margin,.3em)}.fa ...
# .vue-recycle-scroller{position:relative}.vue-recycle-scroller.direction-vertical:not(.page-mode){overflow-y:auto}.vue-recycle-scroller.direction-horizontal:not(.page-mode){overflow-x:auto}.vue-recycle-scroller.direction-horizontal{display:-webkit-box;display:-ms-flexbox;display:flex}.vue-recycle-scroller__slot{-webkit-box-flex:1;-ms-flex:auto 0 0px;flex:auto 0 0}.vue-recycle-scroller__item-wrapper{-webkit-box-flex:1;-ms-flex:1;flex:1;-webkit-box-sizing:border-box;box-sizing:border-box;overflow:hidden;position:relative}.vue-recycle-scroller.ready .vue-recycle-scroller__item-view{position:absolute;top:0;left:0;will-change:transform}.vue-recycle-scroller.direction-vertical .vue-recycle-scroller__item-wrapper{width:100%}.vue-recycle-scroller.direction-horizontal .vue-recycle-scroller__item-wrapper{height:100%}.vue-recycle-scroller.ready.direction-vertical .vue-recycle-scroller__item-view{width:100%}.vue-recycle-scroller.ready.direction-horizontal .vue-recycle-scroller__item-view{height:100%}.resize-observer[data-v-b329ee4c]{border:none;background-color:transparent;opacity:0}.resize-observer[data-v-b329ee4c],.resize-observer[data-v-b329ee4c] object{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;pointer-events:none;display:block;overflow:hidden}
# body{overflow-x:hidden}ion-menu ion-content ion-toolbar,ion-popover ion-toolbar{--background:transparent!important}#app{position:relative;z-index:0}
# .navbar__button__link__item{text-transform:capitalize}.search-overlay{position:fixed;display:block;width:100vw;height:100vh;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);cursor:pointer}.navbar{position:-webkit-sticky;position:sticky;display:flex;background:#060d17;height:56px;width:100%;top:0;margin:0 auto;z-index:100}@media(max-width:1050px){.navbar{max-height:105px}}.navbar__wrapper{display:flex;justify-content:flex-end;width:100%;align-items:center;overflow:visible}@media(max-width:1050px){.navbar__wrapper{justify-content:center}}.navbar.navbar-hide{display:none!important}.navbar.landing-page{background:transparent}@media(min-width:1050px){.navbar.landing-page{height:86px;padding-top:15px;margin-bottom:-86px}.navbar.landing-page .navbar__logo img{width:219px}}@media(max-width:1050px){.navbar.landing-page{margin-bottom:0}}.navbar--hidden,.navbar.landing-page .landing-hide{display:none}.navbar--absolute{position:absolute}@media(max-width:1050px){.navbar{height:105px;align-items:flex-end}}@media(max-width:1050px){.navbar.navbar__button--watchlist a{color:var(--ion-color-primary)!important}}.navbar__logo{-webkit-padding-end:15px;padding-inline-end:15px;display:flex;align-items:center;flex-shrink:0}.navbar__logo img{width:131px}@media(max-width:1050px){.navbar__logo{position:absolute;top:0;width:100%;min-height:46px;display:flex;justify-content:center;align-items:center;margin:0;-webkit-padding-end:0;padding-inline-end:0}}.navbar--is-mobile .navbar__logo{justify-content:left}.navbar--is-ios .navbar__logo{height:56px}.navbar__logo-link{display:flex;align-items:center}.navbar__logo .valentine-link{font-size:24px;margin-top:2px;-webkit-margin-start:8px;margin-inline-start:8px}.navbar.container .navbar__logo{-webkit-margin-start:0;margin-inline-start:0;-webkit-padding-start:0;padding-inline-start:0}.navbar__search{z-index:1;flex-grow:2;height:52px;margin:0;-webkit-margin-end:7px;margin-inline-end:7px;display:flex}.navbar__search .search-suggester .searchbar-input{color:#fff;box-shadow:none;border-radius:4px;font-size:15px;padding:4px 0;-webkit-padding-start:50px;padding-inline-start:50px;-webkit-padding-end:15px;padding-inline-end:15px}@media(max-width:992px){.navbar__search--expanded{left:0;right:0;position:absolute}}.navbar.landing-page .navbar__search{flex-grow:0;width:35em;transition:width .6s;transition-delay:.1s;align-items:center;display:flex}.navbar.landing-page .navbar__search:focus-within{width:100%}@media(max-width:1050px){.navbar.landing-page .navbar__search:focus-within{display:flex;align-items:center;justify-content:space-around}}.navbar__extra{display:flex;min-width:92px}@media(max-width:1050px){.navbar__extra{display:none}}.navbar__extra__small{display:none}@media(max-width:1050px){.navbar__extra__small{display:block;position:absolute;top:0;width:100%}[dir=ltr] .navbar__extra__small{right:0}[dir=rtl] .navbar__extra__small{left:0}.navbar__extra__small--left{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--left{left:4px}[dir=rtl] .navbar__extra__small--left{right:4px}.navbar__extra__small--right{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--right{right:0}[dir=rtl] .navbar__extra__small--right{left:0}}.navbar__extra--remove-spacing{min-width:unset}.navbar__button{height:56px;flex-grow:inherit;cursor:pointer}.navbar__button a{padding:0}.navbar__button>div,.navbar__button__link{justify-content:center}.navbar__button__link{display:flex;align-items:center;height:100%;white-space:nowrap;font-size:14px;color:#999c9f}.navbar__button__link.nav-link-active,.navbar__button__link.router-link-exact-active{font-weight:700;color:#d9e8ed!important}.navbar__button__link__item{margin:0 15px;display:flex;-webkit-margin-end:15px;margin-inline-end:15px}@media(max-width:1050px){.navbar__button--home .navbar__button__link__item,.navbar__button--watchlist .navbar__button__link__item{display:none}}@media(max-width:1050px){.navbar__button--sports .navbar__button__link__item{margin:0 5px}}.navbar_ ...
# .freemium-filter__badge{display:inline-flex;align-items:center;font-size:14px;line-height:22px;letter-spacing:.2px;font-weight:700;text-align:center;color:#fff;background:linear-gradient(-225deg,#5c6374,#3b404e 31%,#272939 68%,#191d2a);padding:2px 7px;border-radius:4px;-webkit-margin-start:8px;margin-inline-start:8px}.freemium-filter__badge--sm{padding:2px 6px;font-size:12px;line-height:16px}.freemium-filter__badge svg{-webkit-margin-end:8px;margin-inline-end:8px}
# .search-suggester__results{overflow:scroll;border-bottom-left-radius:8px;border-bottom-right-radius:8px;height:90vh;max-width:100vw}.search-suggester{position:relative}.search-suggester .sponsored-recommendation-search{margin-top:-10px;z-index:1000;position:relative;display:flex;width:100%}.search-suggester input[type=search]::-webkit-search-cancel-button{display:none}.search-suggester__results{z-index:200;padding:0 8px 8px;margin:-9px 0 0}.search-suggester__results--mobile{padding:0;margin:-11px -1em -.4em}.search-suggester--web{text-align:start;width:100%;padding:0;height:52px;z-index:10}.search-suggester--web ion-searchbar.ios{--background:#10161d;padding:8px;height:52px}.search-suggester--web .searchbar-cancel-button.sc-ion-searchbar-ios{background:#10161d;-webkit-padding-end:8px;padding-inline-end:8px}.search-suggester__searchbar--mobile{padding-top:3px!important;padding-bottom:10px!important}.search-suggester__searchbar--mobile.md{height:52px;--background:#fff;--color:var(--ion-color-tertiary-shade)!important}.search-suggester__searchbar--mobile.md .searchbar-input{border-radius:4px!important}.search-suggester__searchbar input::-webkit-search-cancel-button{-webkit-appearance:none}.search-suggester__searchbar .searchbar-clear-icon{color:var(--ion-color-secondary)!important}.search-suggester__blocking{position:absolute;width:100%;padding:8px}.search-suggester__blocking__input{width:100%;height:38px;display:flex;align-items:center;background-color:var(--ion-color-tertiary-shade)}.searchbar-clear-button.sc-ion-searchbar-md{color:#fff!important}
# .logged-in[data-v-6aa447f4]{padding:0 15px;color:var(--ion-color-primary);font-size:18px}.logged-in[data-v-6aa447f4],.not-logged-in[data-v-6aa447f4]{height:100%;display:flex;align-items:center}@media(max-width:1050px){.not-logged-in__button[data-v-6aa447f4]{display:none}}.not-logged-in__icon[data-v-6aa447f4]{display:none;font-size:16px;cursor:pointer}@media(max-width:1050px){.not-logged-in__icon[data-v-6aa447f4]{display:block}}@media(max-width:1050px){.not-logged-in[data-v-6aa447f4]{padding:0 15px}}
# .basic-button{background:none;border:none;margin:0;padding:0;outline:none;white-space:nowrap;cursor:pointer}.basic-button__content{overflow:hidden;text-overflow:ellipsis}.basic-button.sm{font-size:13px;padding:.4rem 1.35rem}.basic-button.md{padding:.75rem 1.5rem}.basic-button.lg{font-size:18px;padding:1.6rem 4rem}.basic-button.lg.rounded{border-radius:8px}.basic-button.w-full{width:100%}.basic-button.rounded{border-radius:4px}.basic-button.uppercase{text-transform:uppercase}.basic-button.primary{font-weight:700;background-color:#fbc500;color:#000}.basic-button.primary.bg-none{color:#fbc500}.basic-button.primary.bg-none:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary.border{color:#fbcb1a;border:1px solid #fbcb1a}.basic-button.primary.border:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary:hover{background-color:#ddad00}.basic-button.secondary{color:#fff;font-weight:700;background-color:#4c5a67}.basic-button.secondary.bg-none{color:#4c5a67}.basic-button.secondary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary.border{border:1px solid #5e6b76}.basic-button.secondary.border:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary:hover{background-color:#ddad00}.basic-button.tertiary{color:#fff;background-color:#1c252f}.basic-button.tertiary.bg-none{color:#1c252f}.basic-button.tertiary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.tertiary.border{border:1px solid #383d47}.basic-button.tertiary.border:hover{background-color:rgba(56,61,71,.1)}.basic-button.tertiary:hover{background-color:#383d47}.basic-button.light{color:#d9e8ed;background-color:#1c252f}.basic-button.light:hover{background-color:#383d47}.basic-button.medium{color:#fff;background-color:#8c8c8c}.basic-button.medium.border{color:#999c9f;border:1px solid #999c9f}.basic-button.medium.border:hover{background-color:rgba(153,156,159,.1)}.basic-button.medium:hover{background-color:#999c9f}.basic-button.bg-none{background:transparent}.basic-button.disabled{cursor:default;opacity:.5;pointer-events:none}
# .navbar__button__link[data-v-701c8f36]{background:none;border:none;outline:none;cursor:pointer}
# .login-menu-button__button[data-v-4dfb297b]{all:unset;display:flex;align-items:center;height:100%;padding:0 15px;font-size:16px}.login-menu-button__button--logged-in[data-v-4dfb297b]{color:var(--ion-color-primary)}
# .popular-page__spinner{width:100%;height:50vh;display:flex;align-items:center;justify-content:center}#tyche_trendi_video_container.jw-no-consent{transform:translateY(-50px)}@media(max-width:768px){#tyche_trendi_video_container.jw-no-consent{transform:translateY(-100px)}}#tyche_trendi_video_container.jw-android-banner{transform:translateY(-80px)}.overlay-blocking-element{position:absolute;height:100vh;width:100vw}.content-provider-content{position:relative;width:100vw}.content-provider-content.full-height{min-height:100vh}.catalog-title{display:flex;align-items:center;justify-content:flex-start;width:100%}@media(max-width:1050px){.catalog-title h2{-webkit-margin-start:15px;margin-inline-start:15px}}.show-filters{margin:0 15px}@media(max-width:599px){.show-filters__text{display:none}}.sponsored-recommendation{grid-area:double-poster;height:100%}@media(max-width:540px){.sponsored-recommendation{height:270px}}
# .content[data-v-d7672432]{min-height:100vh;display:flex;flex-direction:column;--padding-top:56px}@media(max-width:1050px){.content[data-v-d7672432]{--padding-top:105px}}
# .toggle-filters{display:flex;align-items:center;margin:10px}.toggle-filters__label{-webkit-margin-end:5px;margin-inline-end:5px}.toggle-filters.border.bg-none{color:#d5d5d5}.content-container{display:flex;align-items:center;position:relative}.center-banner{display:flex;justify-content:center}.display-none{display:none}.content-header{min-height:138px;max-height:138px;overflow:hidden;position:relative;width:100%}@media(max-width:1050px){.content-header{padding-left:15px;padding-right:15px}}.content-header:hover{cursor:pointer}.content-header--expanded{max-height:none}.content-header--no-text{min-height:70px}.content-header--gradient{position:absolute;bottom:0;width:100%;text-align:center;margin:0;padding:15px 0;background-image:linear-gradient(180deg,rgba(6,13,23,0),var(--ion-background-color))}[dir=ltr] .content-header--gradient{left:0}[dir=rtl] .content-header--gradient{right:0}.content-header h1{-webkit-padding-end:15px;padding-inline-end:15px}.content-header__search-heading{flex-grow:1;display:flex;align-items:center}@media(max-width:1050px){.content-header__search-heading{padding-left:15px;padding-right:15px}}.content-header__search-heading h1{font-size:24px;line-height:32px;font-weight:700;color:#d9e8ed}@media(max-width:767px){.content-header__search-heading h1{font-size:16px;line-height:24px}}.content-header__search-heading div{font-size:15px;padding:10px 0 5px}.content-header__caret{position:absolute;top:18px}[dir=ltr] .content-header__caret{right:0}[dir=rtl] .content-header__caret{left:0}@media(max-width:1050px){[dir=ltr] .content-header__caret{right:20px}[dir=rtl] .content-header__caret{left:20px}}
# ...
#           <a data-v-01a44aa4="" href="/in/guide/best-kriti-sanon-movies-where-to-watch">
#            10 Best Kriti Sanon Movies and Where to Stream Them
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </footer>
#      <!-- -->
#     </div>
#    </div>
#    <style>
#     null
#    </style>
#    <div>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <!-- -->
#    </div>
#   </div>
#   <script data-vue-ssr-data="">
#    window.__DATA__={"state":{"app":{"geoLocation":"us","seoUser":true},"constant":{"providers":[{"clearName":"Netflix","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F207360008\u002F{profile}\u002Fnetflix.{format}","monetizationTypes":["FLATRATE"],"packageId":8,"selected":false,"shortName":"nfx","slug":"netflix","technicalName":"netflix"},{"clearName":"Amazon Prime Video","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F52449861\u002F{profile}\u002Famazonprimevideo.{format}","monetizationTypes":["FLATRATE"],"packageId":119,"selected":false,"shortName":"prv","slug":"amazon-prime-video","technicalName":"amazonprimevideo"},{"clearName":"Apple TV Plus","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F152862153\u002F{profile}\u002Fappletvplus.{format}","monetizationTypes":["FLATRATE"],"packageId":350,"selected":false,"shortName":"atp","slug":"apple-tv-plus","technicalName":"appletvplus"},{"clearName":"Apple TV","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F190848813\u002F{profile}\u002Fitunes.{format}","monetizationTypes":["BUY","RENT"],"packageId":2,"selected":false,"shortName":"itu","slug":"apple-tv","technicalName":"itunes"},{"clearName":"Crunchyroll","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F127445869\u002F{profile}\u002Fcrunchyroll.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":283,"selected":false,"shortName":"cru","slug":"crunchyroll","technicalName":"crunchyroll"},{"clearName":"Hotstar","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F240029443\u002F{profile}\u002Fhotstar.{format}","monetizationTypes":["FLATRATE"],"packageId":122,"selected":false,"shortName":"hst","slug":"hotstar","technicalName":"hotstar"},{"clearName":"Voot","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F4233119\u002F{profile}\u002Fvoot.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":121,"selected":false,"shortName":"voo","slug":"voot","technicalName":"voot"},{"clearName":"Jio Cinema","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F85114140\u002F{profile}\u002Fjiocinema.{format}","monetizationTypes":["FLATRATE"],"packageId":220,"selected":false,"shortName":"jio","slug":"jio-cinema","technicalName":"jiocinema"},{"clearName":"Zee5","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F93795879\u002F{profile}\u002Fzee5.{format}","monetizationTypes":["ADS","FLATRATE","FREE"],"packageId":232,"selected":false,"shortName":"zee","slug":"zee5","technicalName":"zee5"},{"clearName":"Eros Now","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F247912837\u002F{profile}\u002Ferosnow.{format}","monetizationTypes":["FLATRATE"],"packageId":218,"selected":false,"shortName":"ern","slug":"eros-now","technicalName":"erosnow"},{"clearName":"Google Play Movies","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F169478387\u002F{profile}\u002Fplay.{format}","monetizationTypes":["BUY","RENT"],"packageId":3,"selected":false,"shortName":"ply","slug":"google-play-movies","technicalName":"play"},{"clearName":"MUBI","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F164970114\u002F{profile}\u002Fmubi.{format}","monetizationTypes":["FLATRATE","RENT"],"packageId":11,"selected":false,"shortName":"mbi","slug":"mubi","technicalName":"mubi"},{"clearName":"Sony Liv","hasSport":true,"hasTitles":true,"icon":"\u002Ficon\u002F207468084\u002F{profile}\u002Fsonyliv.{format}","monetizationTypes":["ADS","FLATRATE"],"packageId":237,"selected":false,"shortName":"snl","slug":"sony-liv","technicalName":"sonyliv"},{"clearName":"YouTube","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F59562423\u002F{profile}\u002Fyoutube.{format}","monetizationTypes":["BUY","FLATRATE","RENT"],"packageId":192,"selected":false,"shortName":"yot","slug":"youtube","technicalName":"youtube"},{"clearName":"GuideDoc","hasSport":false,"hasTitles":true,"icon":"\u002Ficon\u002F2625277\u002F{profile}\u002Fguidedoc.{format}","monetizationTypes":["FLATRATE"],"packageId":100,"selected":false,"shor ...
#   </script>
#   <script>
#    window.__APOLLO_STATE__={"defaultClient":{"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13":{"organization":"CBFC","__typename":"AgeCertification"},"ROOT_QUERY":{"ageCertifications({\"country\":\"IN\"})":[{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).0","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).1","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).2","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).3","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).4","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).5","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).6","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).7","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).8","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).9","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).10","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).11","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).12","typename":"AgeCertification"},{"type":"id","generated":true,"id":"ROOT_QUERY.ageCertifications({\"country\":\"IN\"}).13","typename":"AgeCertification"}],"ageCertifications({\"country\":\"IN\",\"objectType\":\"MOVIE\"})":[{"type":"id","generated":false,"id":"AgeCertification:27","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:28","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:29","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21388","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21405","typename":"AgeCertification"},{"type":"id","generated":false,"id":"AgeCertification:21427","typename":"AgeCertification"},{"type":"id","generated":false ...
#   </script>
#   <script>
#    // Runtime Env Vars
# 			window.DNS_PREFETCH=[{"rel":"dns-prefetch","href":"https://www.googletagmanager.com/"},{"rel":"dns-prefetch","href":"https://ib.adnxs.com"}];
# 			window.HTTP_PRECONNECT=[{"rel":"preconnect","crossorigin":"use-credentials","href":"https://images.justwatch.com"}];
# 			window.BUILD_CONFIG={"appVersion":"3.8.2","commitHash":"20e5756e8da75867e5a482ada39a796fcaf99c3b","commitShortHash":"20e5756","env":"prod","globals":{"ASSETS_DIR":"appassets","BUILD_TARGET":"SSR","IS_BUILD":true,"IS_SERVE":false,"IS_START":false,"IS_DEV":true,"IS_PROD":false}};
# 			window.JW_CONFIG={"API":"https://apis.justwatch.com/content","ASSETS_URL":"https://www.justwatch.com/static/compile_jw/assets","BRAZE_BASE_URL":"sdk.iad-05.braze.com","BRAZE_WEB_API_KEY":"1aad19f0-6f9f-4fd5-9a05-9ca5499795f9","CHECKIP_URL":"https://info.justwatch.com ","CLICK_URL":"https://click.justwatch.com","DISCOVERY_URL":"https://apis.justwatch.com/discovery","DOMAIN":"justwatch.com","EVENT_URL":"https://apis.justwatch.com/event","EXPERIMENT_CONFIG_URL":"https://apis.justwatch.com/configuration/experiments","FACEBOOK_APP_ID":"794243977319785","FEEDBACK_URL":"https://apis.justwatch.com/feedback","FIREBASE_API_KEY":"AIzaSyDv6JIzdDvbTBS-JWdR4Kl22UvgWGAyuo8","FIREBASE_APP_ID":"1:413470318987:web:28b910bbf217d7d5034f8e","FIREBASE_AUTH_DOMAIN":"accounts.justwatch.com","FIREBASE_MESSAGING_SENDER_ID":"413470318987","FIREBASE_PROJECT_ID":"justwatch-apps-beta","FIREBASE_STORAGE_BUCKET":"justwatch-apps-beta.appspot.com","GOOGLE_CLIENT_ID":"532718895899-fhbuhnd9nsrae0ivadejq35vsr2sgr0l.apps.googleusercontent.com","GOOGLE_MAPS_API_KEY":"AIzaSyBVU86Zuf3v_6W8dnnV9BRKe_YSBXroqCA","GRAPHQL_URL":"https://apis.justwatch.com/graphql","IDENTITY_URL":"https://apis.justwatch.com/identity","ID_URL":"https://i.tw.cx","IMAGESCALER_FAST_URL":"https://www.justwatch.com/images","IMAGESCALER_URL":"https://images.justwatch.com","JOBSITE_URL":"https://www.justwatch.com/talent/jobs","ITUNES_APP_ID":"979227482","NOTIFICATION_URL":"https://apis.justwatch.com/notification","PLOT_RECOMMENDER_URL":"https://apis.justwatch.com/plotpoint","REVENUE_CAT_API_URL":"https://api.revenuecat.com/v1","REVENUE_CAT_PUBLIC_KEY":"sijZLciaBRrTwuIAeBkAqzQNtMNQaXqV","SENTRY_DSN":"https://ad6b9c4b3a3f4e998e38c3c7ed92574f@sentry.justwatch.com/4","SENTRY_DSN_SSR_CLIENT":"https://e83b625f73464fe9af5aea210630233c@sentry.justwatch.com/9","SNOWPLOW_COLLECTOR_ENDPOINT":"sp.justwatch.com","USER_URL":"https://userapi.justwatch.com","WRITE_URL":"https://apis.justwatch.com/personalization","AD_TAG":"https://pubads.g.doubleclick.net/gampad/ads?iu=/21679119891/video_ads_trailers&description_url=https%3A%2F%2Fwww.justwatch.com%2F&tfcd=0&npa=0&sz=640x360%7C640x480&gdfp_req=1&output=vast&unviewed_position_start=1&env=vp&impl=s&correlator=&vad_type=linear","ZENDESK_SUBDOMAIN":"https://justwatch.zendesk.com","SUBSCRIPTIONS":{"regular":{"id":"prod_LKEY8MLBOZwwQN","priceId":"price_1Kda5MKD0TTmBHo0KnyileCK","type":"regular","timeframe":"monthly","price":2.49},"yearly":{"id":"prod_NzlZqI8lGP1soA","priceId":"price_1NDm2ZKD0TTmBHo0u99J14yr","type":"yearly","timeframe":"yearly","price":19.99},"monthly":{"id":"prod_NzlSDe5AXBSi4X","priceId":"price_1NDlvNKD0TTmBHo08pBWfjIZ","type":"monthly","timeframe":"monthly","price":3.99},"onetime":{"id":"prod_NzlbbPqyeBPsT8","priceId":"price_1NDm4CKD0TTmBHo0KnsX1AJw","type":"onetime","timeframe":"one time","price":59.99}}};
# 			window.IMG_POSTER_LOAD_COUNT=4;
# 			window.IMG_PROVIDERS_BAR_LOAD_COUNT=7;
# 			window.IMG_PROVIDERS_BUY_BOX_COUNT=6;
# 			window.IMG_NEW_TIMELINE_ROWS=1;
# 			window.IS_CANARY=false;
# 			window.NEW_TIMELINE_BUCKETS_LIMIT=4;
# 			window.NEW_TIMELINE_TITLES_PER_BUCKET_LIMIT=10;
# 			window.VUE_APP_TESTS_E2E=false;
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_runtime.ec870570.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_popular.85852750.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_chunk-48f5c245.0c44ec24.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_title-list-grid.53749718.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_chunk-09eadbc1.4f506bd4.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_chunk-2c17f909.dcf82350.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_default-footer.25da163f.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_low-priority-components.0e781e3d.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.vue.53092bae.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.vue-router.3d04e099.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.firebase.3638ea87.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.graphql.f600a27c.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.sentry.6d850964.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.sentry-internal.b5967eab.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.fortawesome.0f6b93f7.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.apollo-client.25b9e10b.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_npm.localforage.67c908d6.js" type="module">
#   </script>
#   <script defer="" src="/appassets/js/1707247534494_app.4f3244db.js" type="module">
#   </script>
#   <script>
#    !function(){var e=document,t=e.createElement("script");if(!("noModule"in t)&&"onbeforeload"in t){var n=!1;e.addEventListener("beforeload",function(e){if(e.target===t)n=!0;else if(!e.target.hasAttribute("nomodule")||!n)return;e.preventDefault()},!0),t.type="module",t.src=".",e.head.appendChild(t),t.remove()}}();
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_runtime.cf763861.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.vue.53092bae.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.vue-router.3d04e099.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.firebase.3638ea87.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.node-libs-browser.84e0af7d.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.graphql.f600a27c.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.sentry.6d850964.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.sentry-internal.b5967eab.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.uvue.2246dd71.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.fortawesome.0f6b93f7.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.apollo-client.25b9e10b.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_npm.localforage.67c908d6.js" type="text/javascript">
#   </script>
#   <script nomodule="" src="appassets/js/1707247230330_app.570c2c4d.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Finding all anchor elements with the specified class
anchor_elements = soup.find_all('a', class_='title-list-grid__item--link')

# Initializing an empty list to store the tvshow URLs
tvshow_urls = []

# Loop through each anchor element and extract the 'href' attribute
for anchor_element in anchor_elements:
  href_value = anchor_element.get('href')
  full_url = f'https://www.justwatch.com{href_value}'
  tvshow_urls.append(full_url)

# Printing the list of tvshow URLs
print(tvshow_urls)
# Out:
# ['https://www.justwatch.com/in/tv-show/jack-reacher', 'https://www.justwatch.com/in/tv-show/true-detective', 'https://www.justwatch.com/in/tv-show/indian-police-force', 'https://www.justwatch.com/in/tv-show/mirzapur', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024', 'https://www.justwatch.com/in/tv-show/game-of-thrones', 'https://www.justwatch.com/in/tv-show/bigg-boss', 'https://www.justwatch.com/in/tv-show/panchayat', 'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman', 'https://www.justwatch.com/in/tv-show/killer-soup', 'https://www.justwatch.com/in/tv-show/death-and-other-details', 'https://www.justwatch.com/in/tv-show/berlin', 'https://www.justwatch.com/in/tv-show/yellowstone', 'https://www.justwatch.com/in/tv-show/maharani-2021', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen', 'https://www.justwatch.com/in/tv-show/the-last-of-us', 'https://www.justwatch.com/in/tv-show/farzi', 'https://www.justwatch.com/in/tv-show/the-bear', 'https://www.justwatch.com/in/tv-show/fargo', 'https://www.justwatch.com/in/tv-show/monarch-legacy-of-monsters', 'https://www.justwatch.com/in/tv-show/the-freelancer', 'https://www.justwatch.com/in/tv-show/paperhouse', 'https://www.justwatch.com/in/tv-show/marry-my-husband', 'https://www.justwatch.com/in/tv-show/my-demon', 'https://www.justwatch.com/in/tv-show/succession', 'https://www.justwatch.com/in/tv-show/superman-and-lois', 'https://www.justwatch.com/in/tv-show/mr-and-mrs-smith', 'https://www.justwatch.com/in/tv-show/fool-me-once', 'https://www.justwatch.com/in/tv-show/aashram', 'https://www.justwatch.com/in/tv-show/ek-thi-begum', 'https://www.justwatch.com/in/tv-show/griselda', 'https://www.justwatch.com/in/tv-show/mastram', 'https://www.justwatch.com/in/tv-show/loki', 'https://www.justwatch.com/in/tv-show/the-railway-men-the-untold-story-of-bhopal-1984', 'https://www.justwatch.com/in/tv-show/gandii-baat', 'https://www.justwatch.com/in/tv-show/what-if-2021', 'https://www.justwatch.com/in/tv-show/breaking-bad', 'https://www.justwatch.com/in/tv-show/flames', 'https://www.justwatch.com/in/tv-show/percy-jackson-and-the-olympians', 'https://www.justwatch.com/in/tv-show/gullak', 'https://www.justwatch.com/in/tv-show/masters-of-the-air', 'https://www.justwatch.com/in/tv-show/house', 'https://www.justwatch.com/in/tv-show/deaths-game', 'https://www.justwatch.com/in/tv-show/echo', 'https://www.justwatch.com/in/tv-show/the-family-man', 'https://www.justwatch.com/in/tv-show/taaza-khabar', 'https://www.justwatch.com/in/tv-show/scam-1992', 'https://www.justwatch.com/in/tv-show/ted', 'https://www.justwatch.com/in/tv-show/love-never-lies-poland', 'https://www.justwatch.com/in/tv-show/asur', 'https://www.justwatch.com/in/tv-show/aarya', 'https://www.justwatch.com/in/tv-show/euphoria', 'https://www.justwatch.com/in/tv-show/dehati-ladke', 'https://www.justwatch.com/in/tv-show/shark-tank-india', 'https://www.justwatch.com/in/tv-show/aspirants', 'https://www.justwatch.com/in/tv-show/dark-desire', 'https://www.justwatch.com/in/tv-show/lucifer', 'https://www.justwatch.com/in/tv-show/expats', 'https://www.justwatch.com/in/tv-show/scam-2003-the-telgi-story', 'https://www.justwatch.com/in/tv-show/detective-forst', 'https://www.justwatch.com/in/tv-show/the-brothers-sun', 'https://www.justwatch.com/in/tv-show/spartacus', 'https://www.justwatch.com/in/tv-show/koffee-with-karan', 'https://www.justwatch.com/in/tv-show/maharani', 'https://www.justwatch.com/in/tv-show/perilloor-premier-league', 'https://www.justwatch.com/in/tv-show/peaky-blinders', 'https://www.justwatch.com/in/tv-show/modern-family', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon', 'https://www.justwatch.com/in/tv-show/criminal-record', 'https://www.justwatch.com/in/tv-show/the-boys', 'https://www.justwatch.com/in/tv-show/the-curse', 'https://www.justwatch.com/in/tv-show/naruto-shippuden', 'https://www.justwatch.com/in/tv-show/stranger-things', 'https://www.justwatch.com/in/tv-show/kaala-paani', 'https://www.justwatch.com/i ...

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Initializing an empty list to store TV show titles
tvshow_title = []

# Iterating through each anchor element in the anchor_elements list
for anchor_element in anchor_elements:
    # Extracting the last part of the href attribute (the TV show title) and stripping whitespace
    name = anchor_element.get('href').split('/')[-1].strip()

    # Appending the extracted and stripped TV show title to the tvshow_title list
    tvshow_title.append(name)

# Printing the list containing TV show titles
print(tvshow_title)
# Out:
# ['jack-reacher', 'true-detective', 'indian-police-force', 'mirzapur', 'solo-leveling-2024', 'game-of-thrones', 'bigg-boss', 'panchayat', 'the-legend-of-hanuman', 'killer-soup', 'death-and-other-details', 'berlin', 'yellowstone', 'maharani-2021', 'jujutsu-kaisen', 'the-last-of-us', 'farzi', 'the-bear', 'fargo', 'monarch-legacy-of-monsters', 'the-freelancer', 'paperhouse', 'marry-my-husband', 'my-demon', 'succession', 'superman-and-lois', 'mr-and-mrs-smith', 'fool-me-once', 'aashram', 'ek-thi-begum', 'griselda', 'mastram', 'loki', 'the-railway-men-the-untold-story-of-bhopal-1984', 'gandii-baat', 'what-if-2021', 'breaking-bad', 'flames', 'percy-jackson-and-the-olympians', 'gullak', 'masters-of-the-air', 'house', 'deaths-game', 'echo', 'the-family-man', 'taaza-khabar', 'scam-1992', 'ted', 'love-never-lies-poland', 'asur', 'aarya', 'euphoria', 'dehati-ladke', 'shark-tank-india', 'aspirants', 'dark-desire', 'lucifer', 'expats', 'scam-2003-the-telgi-story', 'detective-forst', 'the-brothers-sun', 'spartacus', 'koffee-with-karan', 'maharani', 'perilloor-premier-league', 'peaky-blinders', 'modern-family', 'house-of-the-dragon', 'criminal-record', 'the-boys', 'the-curse', 'naruto-shippuden', 'stranger-things', 'kaala-paani', 'kubra', 'better-call-saul', 'one-piece-2023', 'the-unwanted-undead-adventurer', 'luther', 'mashle-magic-and-muscles', 'under-the-dome', 'one-punch-man', 'cubicles', 'undekhi', 'the-walking-dead', 'the-rookie', 'naruto', 'college-romance', 'wednesday', 'shameless', 'how-i-met-your-mother', 'coegangyagu', 'gyeongseong-creature', 'attack-on-titan', 'apharan', 'the-big-bang-theory', 'the-flash', 'young-sheldon', 'beef', 'suits']

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Initializing an empty list to store TV show release years
tvshow_release_year = []

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content for the current TV show URL
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the span element with class 'text-muted'
    year = soup.find('span', class_='text-muted')

    # Extracting the release year from the text content of the span element
    # If the span element is not found, set release year to 'NA'
    tvshow_release_year.append(year.text.split("(")[-1].split(")")[0] if year else 'NA')

# Printing the list containing TV show release years
print(tvshow_release_year)
# Out:
# ['2022', '2014', '2024', '2018', '2024', '2011', '2006', '2020', '2021', '2024', '2024', '2023', '2018', '2021', '2020', '2023', '2023', '2022', '2014', '2023', '2023', '2017', '2024', '2023', '2018', '2021', '2024', '2024', '2020', '2020', '2024', '2020', '2021', '2023', '2018', '2021', '2008', '2018', '2023', '2019', '2024', '2004', '2023', '2024', '2019', '2023', '2020', '2024', '2022', '2020', '2020', '2019', '2023', '2021', '2021', '2020', '2016', '2024', '2023', '2024', '2024', '2010', '2004', '2009', '2024', '2013', '2009', '2022', '2024', '2019', '2023', '2007', '2016', '2023', '2024', '2015', '2023', '2024', '2010', '2023', '2013', '2015', '2019', '2020', '2010', '2018', '2002', '2018', '2022', '2011', '2005', '2022', '2023', '2013', '2018', '2007', '2014', '2017', '2023', '2011']

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Initializing an empty list to store TV show genres
tvshow_genres = []

# Iterating through each TV show URL
for url in tvshow_urls:
  page = requests.get(url)

  # Creating a BeautifulSoup object to parse the HTML content
  soup = BeautifulSoup(page.text, 'html.parser')

  # Finding the h3 element with class 'detail-infos__subheading' and text 'Genres'
  heading = soup.find('h3', class_='detail-infos__subheading', string='Genres')

  # Checking if the heading is found
  if heading:
    # Finding the next sibling div with class 'detail-infos__value'
    genre_div = heading.find_next_sibling('div', class_='detail-infos__value')

    # Checking if the genre_div is found
    if genre_div:
      # Appending the stripped text of genre_div to the tvshow_genres list
      tvshow_genres.append(genre_div.text.strip())
    else:
      # Appending 'NA' if the genre_div is not found
      tvshow_genres.append('NA')
  else:
    # Appending 'NA' if the heading is not found
    tvshow_genres.append('NA')

# Printing the list containing TV show genres for each URL
print(tvshow_genres)
# Out:
# ['Drama, Mystery & Thriller, Action & Adventure, Crime', 'Drama, Crime, Mystery & Thriller', 'Action & Adventure, Crime', 'Crime, Action & Adventure, Drama, Mystery & Thriller', 'Fantasy, Animation, Action & Adventure, Science-Fiction', 'Drama, Action & Adventure, Science-Fiction, Fantasy', 'Reality TV, Kids & Family', 'Comedy, Drama', 'Animation, Action & Adventure, Fantasy', 'Comedy, Drama, Mystery & Thriller', 'Drama, Crime, Mystery & Thriller', 'Drama, Action & Adventure, Crime, Mystery & Thriller', 'Drama, Western', 'Drama', 'Animation, Action & Adventure, Fantasy, Mystery & Thriller, Science-Fiction', 'Drama, Science-Fiction, Mystery & Thriller, Action & Adventure, Horror', 'Drama, Crime, Mystery & Thriller', 'Drama, Comedy', 'Crime, Drama, Mystery & Thriller', 'Drama, Science-Fiction, Action & Adventure', 'Action & Adventure, Mystery & Thriller, Drama', 'Action & Adventure, Crime, Drama, Mystery & Thriller, Made in Europe', 'Romance, Comedy, Drama, Fantasy, Science-Fiction', 'Science-Fiction, Drama, Fantasy, Romance, Comedy', 'Drama, Comedy', 'Science-Fiction, Drama, Romance, Action & Adventure', 'Drama, Comedy, Action & Adventure, Crime, Mystery & Thriller', 'Crime, Drama, Mystery & Thriller', 'Crime, Drama, Mystery & Thriller', 'Crime, Drama, Mystery & Thriller', 'Crime, Drama', 'Drama, Comedy, Fantasy', 'Fantasy, Science-Fiction, Action & Adventure, Drama', 'Drama, History, Mystery & Thriller', 'Crime, Drama, Mystery & Thriller', 'Animation, Action & Adventure, Science-Fiction', 'Crime, Drama, Mystery & Thriller', 'Drama, Comedy, Romance, Made in Europe', 'Drama, Action & Adventure, Science-Fiction, Kids & Family, Fantasy', 'Drama, Kids & Family, Comedy', 'War & Military, Drama, Action & Adventure, Mystery & Thriller', 'Drama', 'Science-Fiction, Drama, Fantasy', 'Drama, Action & Adventure, Science-Fiction, Crime', 'Drama, Action & Adventure, Comedy', 'Drama, Science-Fiction, Mystery & Thriller, Action & Adventure, Comedy, Fantasy', 'Mystery & Thriller, Crime, Drama', 'Comedy', 'Reality TV', 'Mystery & Thriller, Crime, Drama', 'Drama, Mystery & Thriller, Crime, Action & Adventure', 'Drama', 'Drama', 'Reality TV', 'Drama', 'Mystery & Thriller, Drama', 'Crime, Science-Fiction, Drama, Fantasy', 'Drama', 'Drama, Crime', 'Crime, Drama', 'Action & Adventure, Comedy, Drama, Crime', 'Drama, Romance, Action & Adventure', 'Comedy', 'Drama', 'Comedy, Drama', 'Drama, Crime', 'Comedy, Drama, Romance', 'Science-Fiction, Drama, Action & Adventure, Romance, Fantasy', 'Crime, Drama, Mystery & Thriller', 'Science-Fiction, Action & Adventure, Comedy, Crime, Drama', 'Comedy, Drama, Mystery & Thriller', 'Action & Adventure, Science-Fiction, Comedy, Drama, Fantasy, Animation', 'Science-Fiction, Drama, Mystery & Thriller, Fantasy, Horror', 'Mystery & Thriller, Drama', 'Drama, Mystery & Thriller', 'Crime, Drama', 'Science-Fiction, Action & Adventure, Comedy, Drama, Fantasy', 'Action & Adventure, Science-Fiction', 'Crime, Drama, Mystery & Thriller, Made in Europe', 'Fantasy, Animation, Action & Adventure, Comedy, Science-Fiction', 'Mystery & Thriller, Science-Fiction, Drama', 'Action & Adventure, Comedy, Animation, Kids & Family, Fantasy, Science-Fiction', 'Drama, Comedy', 'Crime, Drama', 'Drama, Science-Fiction, Action & Adventure, Horror, Mystery & Thriller', 'Crime, Drama, Comedy, Action & Adventure', 'Action & Adventure, Science-Fiction, Animation, Comedy, Fantasy', 'Comedy, Drama, Romance', 'Science-Fiction, Comedy, Crime, Fantasy, Kids & Family, Horror', 'Drama, Comedy', 'Comedy, Drama, Romance', 'Reality TV, Sport', 'Horror, Mystery & Thriller, Action & Adventure, Drama, History', 'Horror, Animation, Action & Adventure, Drama, Fantasy, Science-Fiction', 'Drama, Crime, Action & Adventure, Mystery & Thriller', 'Comedy, Romance', 'Drama, Science-Fiction, Action & Adventure', 'Comedy, Kids & Family', 'Comedy, Drama', 'Comedy, Drama']

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Initializing a dictionary to store rating values for each tv show URL
tvshow_ratings = {}

# Iterating through each  tv show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for rating in case it's not found
    rating_value = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Rating'
        if subheading and 'Rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            rating_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the rating_div is found
            if rating_div:
                # Extracting the rating value
                rating_value = rating_div.text.strip()

    # Storing the rating value in the dictionary with the  tv show URL as the key
    tvshow_ratings[url] = rating_value

# Print the dictionary containing rating values for each tv show URL
print(tvshow_ratings)
# Out:
# {'https://www.justwatch.com/in/tv-show/jack-reacher': '8.1  (192k)', 'https://www.justwatch.com/in/tv-show/true-detective': '8.9  (629k)', 'https://www.justwatch.com/in/tv-show/indian-police-force': '5.7  (49k)', 'https://www.justwatch.com/in/tv-show/mirzapur': '8.5  (80k)', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024': '8.4  (6k)', 'https://www.justwatch.com/in/tv-show/game-of-thrones': '9.2  (2m)', 'https://www.justwatch.com/in/tv-show/bigg-boss': '3.7  (3k)', 'https://www.justwatch.com/in/tv-show/panchayat': '8.9  (83k)', 'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman': '9.2  (11k)', 'https://www.justwatch.com/in/tv-show/killer-soup': '6.3  (3k)', 'https://www.justwatch.com/in/tv-show/death-and-other-details': '7.0  (3k)', 'https://www.justwatch.com/in/tv-show/berlin': '7.0  (23k)', 'https://www.justwatch.com/in/tv-show/yellowstone': '8.7  (207k)', 'https://www.justwatch.com/in/tv-show/maharani-2021': '7.9  (8k)', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen': '8.6  (105k)', 'https://www.justwatch.com/in/tv-show/the-last-of-us': '8.8  (495k)', 'https://www.justwatch.com/in/tv-show/farzi': '8.4  (43k)', 'https://www.justwatch.com/in/tv-show/the-bear': '8.6  (192k)', 'https://www.justwatch.com/in/tv-show/fargo': '8.9  (412k)', 'https://www.justwatch.com/in/tv-show/monarch-legacy-of-monsters': '7.0  (31k)', 'https://www.justwatch.com/in/tv-show/the-freelancer': '8.1  (5k)', 'https://www.justwatch.com/in/tv-show/paperhouse': '8.2  (524k)', 'https://www.justwatch.com/in/tv-show/marry-my-husband': '8.3  (1k)', 'https://www.justwatch.com/in/tv-show/my-demon': '7.8  (6k)', 'https://www.justwatch.com/in/tv-show/succession': '8.9  (259k)', 'https://www.justwatch.com/in/tv-show/superman-and-lois': '7.8  (39k)', 'https://www.justwatch.com/in/tv-show/mr-and-mrs-smith': '6.7  (8k)', 'https://www.justwatch.com/in/tv-show/fool-me-once': '6.8  (42k)', 'https://www.justwatch.com/in/tv-show/aashram': '7.4  (32k)', 'https://www.justwatch.com/in/tv-show/ek-thi-begum': '8.6  (6k)', 'https://www.justwatch.com/in/tv-show/griselda': '7.5  (9k)', 'https://www.justwatch.com/in/tv-show/mastram': '7.1  (2k)', 'https://www.justwatch.com/in/tv-show/loki': '8.2  (404k)', 'https://www.justwatch.com/in/tv-show/the-railway-men-the-untold-story-of-bhopal-1984': '8.5  (19k)', 'https://www.justwatch.com/in/tv-show/gandii-baat': '3.4  (2k)', 'https://www.justwatch.com/in/tv-show/what-if-2021': '7.5  (88k)', 'https://www.justwatch.com/in/tv-show/breaking-bad': '9.5  (2m)', 'https://www.justwatch.com/in/tv-show/flames': '8.9  (32k)', 'https://www.justwatch.com/in/tv-show/percy-jackson-and-the-olympians': '7.2  (25k)', 'https://www.justwatch.com/in/tv-show/gullak': '9.1  (20k)', 'https://www.justwatch.com/in/tv-show/masters-of-the-air': '8.0  (7k)', 'https://www.justwatch.com/in/tv-show/house': '8.7  (501k)', 'https://www.justwatch.com/in/tv-show/deaths-game': '8.7  (6k)', 'https://www.justwatch.com/in/tv-show/echo': '6.1  (28k)', 'https://www.justwatch.com/in/tv-show/the-family-man': '8.7  (97k)', 'https://www.justwatch.com/in/tv-show/taaza-khabar': '8.1  (47k)', 'https://www.justwatch.com/in/tv-show/scam-1992': '9.3  (150k)', 'https://www.justwatch.com/in/tv-show/ted': '8.0  (15k)', 'https://www.justwatch.com/in/tv-show/love-never-lies-poland': '', 'https://www.justwatch.com/in/tv-show/asur': '8.5  (64k)', 'https://www.justwatch.com/in/tv-show/aarya': '7.9  (13k)', 'https://www.justwatch.com/in/tv-show/euphoria': '8.3  (231k)', 'https://www.justwatch.com/in/tv-show/dehati-ladke': '7.1', 'https://www.justwatch.com/in/tv-show/shark-tank-india': '8.7  (4k)', 'https://www.justwatch.com/in/tv-show/aspirants': '9.2  (309k)', 'https://www.justwatch.com/in/tv-show/dark-desire': '6.5  (9k)', 'https://www.justwatch.com/in/tv-show/lucifer': '8.1  (351k)', 'https://www.justwatch.com/in/tv-show/expats': '5.9  (1k)', 'https://www.justwatch.com/in/tv-show/scam-2003-the-telgi-story': '7.9  (6k)', 'https://www.justwatch.com/in/tv-show/detective-f ...

# %%
# Initializing an empty list to store IMDb ratings
tvshow_imdb_ratings = []

# Iterating through each rating value in the 'ratings' dictionary
for rating in tvshow_ratings.values():
    # Checking if the rating is not 'NA'
    if rating != 'NA':
        # Splitting the rating string and appending the IMDb rating to the list
        tvshow_imdb_ratings.append(rating.split(' ')[0])
    else:
        # If the rating is 'NA', directly appending it to the list
        tvshow_imdb_ratings.append(rating)

# Printing the list containing IMDb ratings
print(tvshow_imdb_ratings)
# Out:
# ['8.1', '8.9', '5.7', '8.5', '8.4', '9.2', '3.7', '8.9', '9.2', '6.3', '7.0', '7.0', '8.7', '7.9', '8.6', '8.8', '8.4', '8.6', '8.9', '7.0', '8.1', '8.2', '8.3', '7.8', '8.9', '7.8', '6.7', '6.8', '7.4', '8.6', '7.5', '7.1', '8.2', '8.5', '3.4', '7.5', '9.5', '8.9', '7.2', '9.1', '8.0', '8.7', '8.7', '6.1', '8.7', '8.1', '9.3', '8.0', '', '8.5', '7.9', '8.3', '7.1', '8.7', '9.2', '6.5', '8.1', '5.9', '7.9', '5.5', '7.7', '8.5', '6.4', '7.2', '7.5', '8.8', '8.5', '8.4', '7.2', '8.7', '7.1', '8.7', '8.7', '8.0', '6.3', '8.8', '8.4', '', '8.4', '7.5', '6.5', '8.7', '8.2', '', '8.1', '8.0', '8.4', '8.3', '8.1', '8.5', '8.3', '8.2', '7.3', '9.0', '8.3', '8.2', '7.5', '7.6', '8.0', '8.4']

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Initializing a dictionary to store age criteria for each TV show URL
tvshow_age_criteria = {}

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for age_rating in case it's not found
    age_rating = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Age Rating'
        if subheading and 'Age rating' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            age_rating_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the age_rating_div is found
            if age_rating_div:
                # Extracting the age rating value
                age_rating = age_rating_div.text.strip()

    # Storing the age rating value in the dictionary with the tv show URL as the key
    tvshow_age_criteria[url] =age_rating

# Print the dictionary containing age_rating_value values for each tv show URL
print(tvshow_age_criteria)
# Out:
# {'https://www.justwatch.com/in/tv-show/jack-reacher': 'A', 'https://www.justwatch.com/in/tv-show/true-detective': 'U', 'https://www.justwatch.com/in/tv-show/indian-police-force': 'A', 'https://www.justwatch.com/in/tv-show/mirzapur': 'NA', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024': 'NA', 'https://www.justwatch.com/in/tv-show/game-of-thrones': 'U', 'https://www.justwatch.com/in/tv-show/bigg-boss': 'NA', 'https://www.justwatch.com/in/tv-show/panchayat': 'NA', 'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman': 'NA', 'https://www.justwatch.com/in/tv-show/killer-soup': 'NA', 'https://www.justwatch.com/in/tv-show/death-and-other-details': 'NA', 'https://www.justwatch.com/in/tv-show/berlin': 'NA', 'https://www.justwatch.com/in/tv-show/yellowstone': 'NA', 'https://www.justwatch.com/in/tv-show/maharani-2021': 'UA', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen': 'NA', 'https://www.justwatch.com/in/tv-show/the-last-of-us': 'A', 'https://www.justwatch.com/in/tv-show/farzi': 'NA', 'https://www.justwatch.com/in/tv-show/the-bear': 'NA', 'https://www.justwatch.com/in/tv-show/fargo': 'NA', 'https://www.justwatch.com/in/tv-show/monarch-legacy-of-monsters': 'NA', 'https://www.justwatch.com/in/tv-show/the-freelancer': 'NA', 'https://www.justwatch.com/in/tv-show/paperhouse': 'NA', 'https://www.justwatch.com/in/tv-show/marry-my-husband': 'NA', 'https://www.justwatch.com/in/tv-show/my-demon': 'NA', 'https://www.justwatch.com/in/tv-show/succession': 'A', 'https://www.justwatch.com/in/tv-show/superman-and-lois': 'NA', 'https://www.justwatch.com/in/tv-show/mr-and-mrs-smith': 'NA', 'https://www.justwatch.com/in/tv-show/fool-me-once': 'NA', 'https://www.justwatch.com/in/tv-show/aashram': 'NA', 'https://www.justwatch.com/in/tv-show/ek-thi-begum': 'NA', 'https://www.justwatch.com/in/tv-show/griselda': 'NA', 'https://www.justwatch.com/in/tv-show/mastram': 'NA', 'https://www.justwatch.com/in/tv-show/loki': 'NA', 'https://www.justwatch.com/in/tv-show/the-railway-men-the-untold-story-of-bhopal-1984': 'NA', 'https://www.justwatch.com/in/tv-show/gandii-baat': 'A', 'https://www.justwatch.com/in/tv-show/what-if-2021': 'NA', 'https://www.justwatch.com/in/tv-show/breaking-bad': 'U', 'https://www.justwatch.com/in/tv-show/flames': 'NA', 'https://www.justwatch.com/in/tv-show/percy-jackson-and-the-olympians': 'NA', 'https://www.justwatch.com/in/tv-show/gullak': 'NA', 'https://www.justwatch.com/in/tv-show/masters-of-the-air': 'A', 'https://www.justwatch.com/in/tv-show/house': 'UA', 'https://www.justwatch.com/in/tv-show/deaths-game': 'NA', 'https://www.justwatch.com/in/tv-show/echo': 'NA', 'https://www.justwatch.com/in/tv-show/the-family-man': 'NA', 'https://www.justwatch.com/in/tv-show/taaza-khabar': 'NA', 'https://www.justwatch.com/in/tv-show/scam-1992': 'NA', 'https://www.justwatch.com/in/tv-show/ted': 'NA', 'https://www.justwatch.com/in/tv-show/love-never-lies-poland': 'NA', 'https://www.justwatch.com/in/tv-show/asur': 'NA', 'https://www.justwatch.com/in/tv-show/aarya': 'NA', 'https://www.justwatch.com/in/tv-show/euphoria': 'A', 'https://www.justwatch.com/in/tv-show/dehati-ladke': 'NA', 'https://www.justwatch.com/in/tv-show/shark-tank-india': 'U', 'https://www.justwatch.com/in/tv-show/aspirants': 'NA', 'https://www.justwatch.com/in/tv-show/dark-desire': 'NA', 'https://www.justwatch.com/in/tv-show/lucifer': 'NA', 'https://www.justwatch.com/in/tv-show/expats': 'NA', 'https://www.justwatch.com/in/tv-show/scam-2003-the-telgi-story': 'NA', 'https://www.justwatch.com/in/tv-show/detective-forst': 'NA', 'https://www.justwatch.com/in/tv-show/the-brothers-sun': 'NA', 'https://www.justwatch.com/in/tv-show/spartacus': 'NA', 'https://www.justwatch.com/in/tv-show/koffee-with-karan': 'A', 'https://www.justwatch.com/in/tv-show/maharani': 'NA', 'https://www.justwatch.com/in/tv-show/perilloor-premier-league': 'U', 'https://www.justwatch.com/in/tv-show/peaky-blinders': 'A', 'https://www.justwatch.com/in/tv-show/modern-family': 'NA', 'https://www.justwat ...

# %%
# Creating a list comprehension to extract age ratings from the 'age_criteria' dictionary
tvshow_age_rating = [rating for rating in tvshow_age_criteria.values()]

# Printing the list containing age ratings
print(tvshow_age_rating)
# Out:
# ['A', 'U', 'A', 'NA', 'NA', 'U', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'UA', 'NA', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'U', 'NA', 'NA', 'NA', 'A', 'UA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'U', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'U', 'A', 'NA', 'A', 'A', 'A', 'NA', 'U', 'NA', 'NA', 'NA', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'NA', 'A', 'NA', 'U', 'U', 'NA', 'NA', 'UA', 'NA', 'U', 'NA', 'U', 'A', 'NA']

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Initializing a dictionary to store production_country for each tv show url
tvshow_production_country = {}

# Iterating through each tv show url
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding all div elements with class 'detail-infos'
    details_divs = soup.find_all('div', class_='detail-infos')

    # Default value for production country in case it's not found
    country = 'NA'

    # Iterating through each 'detail-infos' div
    for detail_div in details_divs:
        # Finding the h3 element with class 'detail-infos__subheading'
        subheading = detail_div.find('h3', class_='detail-infos__subheading')

        # Checking if the subheading contains the text 'Production country'
        if subheading and 'Production country' in subheading.text:
            # Finding the next div with class 'detail-infos__value'
            country_div = detail_div.find('div', class_='detail-infos__value')

            # Checking if the country_div is found
            if country_div:
                # Extracting the country name
                country = country_div .text.strip()

    # Storing the country name  in the dictionary with the tv show url as the key
    tvshow_production_country[url] =country

# Print the dictionary containing counry for each tv show url
print(tvshow_production_country)
# Out:
# {'https://www.justwatch.com/in/tv-show/jack-reacher': 'United States', 'https://www.justwatch.com/in/tv-show/true-detective': 'United States', 'https://www.justwatch.com/in/tv-show/indian-police-force': 'India', 'https://www.justwatch.com/in/tv-show/mirzapur': 'India', 'https://www.justwatch.com/in/tv-show/solo-leveling-2024': 'South Korea, Japan', 'https://www.justwatch.com/in/tv-show/game-of-thrones': 'United States', 'https://www.justwatch.com/in/tv-show/bigg-boss': 'India', 'https://www.justwatch.com/in/tv-show/panchayat': 'India', 'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman': 'India', 'https://www.justwatch.com/in/tv-show/killer-soup': 'India', 'https://www.justwatch.com/in/tv-show/death-and-other-details': 'United States', 'https://www.justwatch.com/in/tv-show/berlin': 'Spain', 'https://www.justwatch.com/in/tv-show/yellowstone': 'United States', 'https://www.justwatch.com/in/tv-show/maharani-2021': 'India', 'https://www.justwatch.com/in/tv-show/jujutsu-kaisen': 'Japan', 'https://www.justwatch.com/in/tv-show/the-last-of-us': 'United States', 'https://www.justwatch.com/in/tv-show/farzi': 'India', 'https://www.justwatch.com/in/tv-show/the-bear': 'United States', 'https://www.justwatch.com/in/tv-show/fargo': 'United States', 'https://www.justwatch.com/in/tv-show/monarch-legacy-of-monsters': 'United States', 'https://www.justwatch.com/in/tv-show/the-freelancer': 'India', 'https://www.justwatch.com/in/tv-show/paperhouse': 'Spain', 'https://www.justwatch.com/in/tv-show/marry-my-husband': 'South Korea', 'https://www.justwatch.com/in/tv-show/my-demon': 'South Korea', 'https://www.justwatch.com/in/tv-show/succession': 'United States', 'https://www.justwatch.com/in/tv-show/superman-and-lois': 'United States', 'https://www.justwatch.com/in/tv-show/mr-and-mrs-smith': 'United States', 'https://www.justwatch.com/in/tv-show/fool-me-once': 'United States, United Kingdom', 'https://www.justwatch.com/in/tv-show/aashram': 'India', 'https://www.justwatch.com/in/tv-show/ek-thi-begum': 'India', 'https://www.justwatch.com/in/tv-show/griselda': 'United States', 'https://www.justwatch.com/in/tv-show/mastram': 'India', 'https://www.justwatch.com/in/tv-show/loki': 'United States', 'https://www.justwatch.com/in/tv-show/the-railway-men-the-untold-story-of-bhopal-1984': 'India', 'https://www.justwatch.com/in/tv-show/gandii-baat': 'India', 'https://www.justwatch.com/in/tv-show/what-if-2021': 'United States', 'https://www.justwatch.com/in/tv-show/breaking-bad': 'United States', 'https://www.justwatch.com/in/tv-show/flames': 'India', 'https://www.justwatch.com/in/tv-show/percy-jackson-and-the-olympians': 'United States', 'https://www.justwatch.com/in/tv-show/gullak': 'India', 'https://www.justwatch.com/in/tv-show/masters-of-the-air': 'United States', 'https://www.justwatch.com/in/tv-show/house': 'United States', 'https://www.justwatch.com/in/tv-show/deaths-game': 'South Korea', 'https://www.justwatch.com/in/tv-show/echo': 'United States', 'https://www.justwatch.com/in/tv-show/the-family-man': 'India', 'https://www.justwatch.com/in/tv-show/taaza-khabar': 'India', 'https://www.justwatch.com/in/tv-show/scam-1992': 'India', 'https://www.justwatch.com/in/tv-show/ted': 'United States', 'https://www.justwatch.com/in/tv-show/love-never-lies-poland': 'Poland', 'https://www.justwatch.com/in/tv-show/asur': 'India', 'https://www.justwatch.com/in/tv-show/aarya': 'India', 'https://www.justwatch.com/in/tv-show/euphoria': 'United States', 'https://www.justwatch.com/in/tv-show/dehati-ladke': 'India', 'https://www.justwatch.com/in/tv-show/shark-tank-india': 'India', 'https://www.justwatch.com/in/tv-show/aspirants': 'India', 'https://www.justwatch.com/in/tv-show/dark-desire': 'Mexico', 'https://www.justwatch.com/in/tv-show/lucifer': 'United States', 'https://www.justwatch.com/in/tv-show/expats': 'United States', 'https://www.justwatch.com/in/tv-show/scam-2003-the-telgi-story': 'India', 'https://www.justwatch.com/in/tv-show/detective-forst': 'Poland', 'https ...

# %%
# Creating a list comprehension to extract production country from the dictionary
tvshow_Production_country=[country for country in tvshow_production_country.values()]
# Printing the list containing Production country
print(tvshow_Production_country)
# Out:
# ['United States', 'United States', 'India', 'India', 'South Korea, Japan', 'United States', 'India', 'India', 'India', 'India', 'United States', 'Spain', 'United States', 'India', 'Japan', 'United States', 'India', 'United States', 'United States', 'United States', 'India', 'Spain', 'South Korea', 'South Korea', 'United States', 'United States', 'United States', 'United States, United Kingdom', 'India', 'India', 'United States', 'India', 'United States', 'India', 'India', 'United States', 'United States', 'India', 'United States', 'India', 'United States', 'United States', 'South Korea', 'United States', 'India', 'India', 'India', 'United States', 'Poland', 'India', 'India', 'United States', 'India', 'India', 'India', 'Mexico', 'United States', 'United States', 'India', 'Poland', 'United States', 'United States', 'India', 'India', 'India', 'United Kingdom', 'United States', 'United States', 'United Kingdom, United States', 'United States', 'United States', 'Japan', 'United States', 'India', 'Turkey', 'United States', 'United States', 'Japan', 'United Kingdom', 'Japan', 'United States', 'Japan', 'India', 'India', 'United States', 'United States', 'Japan', 'India', 'United States', 'United States', 'United States', 'South Korea', 'South Korea', 'Japan', 'India', 'United States', 'United States', 'United States', 'United States', 'United States']

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Initializing an empty list to store streaming platform names
tvshow_streaming_platform = []

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the 'img' element with class 'offer__icon'
    platform = soup.find('img', class_='offer__icon')

    # Checking if the 'platform' element is found
    if platform:
        # Extracting the 'alt' attribute, which contains the platform name
        platform_name = platform['alt']
    else:
        # If 'platform' is not found, assigning 'NA' as the platform name
        platform_name = "NA"

    # Appending the platform name to the list
    tvshow_streaming_platform.append(platform_name)

# Printing the list containing streaming platform names
print(tvshow_streaming_platform)
# Out:
# ['Amazon Prime Video', 'Jio Cinema', 'Amazon Prime Video', 'Amazon Prime Video', 'Crunchyroll', 'Jio Cinema', 'Voot', 'Amazon Prime Video', 'Hotstar', 'Netflix', 'Hotstar', 'Netflix', 'Netflix', 'Sony Liv', 'Crunchyroll', 'Jio Cinema', 'Amazon Prime Video', 'Hotstar', 'NA', 'Apple TV Plus', 'Hotstar', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Amazon Prime Video', 'Amazon Prime Video', 'Netflix', 'MX Player', 'MX Player', 'Netflix', 'NA', 'Hotstar', 'Netflix', 'Alt Balaji', 'Hotstar', 'Netflix', 'Amazon Prime Video', 'NA', 'Sony Liv', 'Apple TV Plus', 'Netflix', 'Amazon Prime Video', 'NA', 'Amazon Prime Video', 'Hotstar', 'Sony Liv', 'NA', 'Netflix', 'Jio Cinema', 'Hotstar', 'Jio Cinema', 'Amazon miniTV', 'Sony Liv', 'Amazon Prime Video', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Sony Liv', 'Netflix', 'Netflix', 'Lionsgate Play', 'Hotstar', 'Hotstar', 'Hotstar', 'Netflix', 'Hotstar', 'Jio Cinema', 'Apple TV Plus', 'Amazon Prime Video', 'Lionsgate Play', 'Crunchyroll', 'Netflix', 'Netflix', 'Netflix', 'Netflix', 'Netflix', 'Crunchyroll', 'Amazon Prime Video', 'Crunchyroll', 'Amazon Prime Video', 'Crunchyroll', 'Sony Liv', 'Sony Liv', 'Netflix', 'NA', 'Netflix', 'Sony Liv', 'Netflix', 'Netflix', 'Hotstar', 'Netflix', 'Netflix', 'NA', 'Voot', 'Netflix', 'NA', 'Amazon Prime Video', 'Netflix', 'Netflix']

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Initializing an empty list to store the number of seasons for each TV show
tvshow_duration = []

# Iterating through each TV show URL
for url in tvshow_urls:
    # Fetching the webpage content
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Finding the 'h2' element with class 'subheading'
    seasons = soup.find('h2', class_='subheading')

    # Checking if the 'seasons' element is found
    if seasons:
        # Appending the text content of 'seasons' to the 'duration' list
        tvshow_duration.append(seasons.text)
    else:
        # If 'seasons' is not found, assigning 'NA' to the 'duration' list
        tvshow_duration.append('NA')

# Printing the list containing the number of seasons for each TV show
print(tvshow_duration)
# Out:
# [' 3 Seasons ', ' 4 Seasons ', ' 1 Seasons ', ' 3 Seasons ', ' 1 Seasons ', ' 8 Seasons ', ' 17 Seasons ', ' 3 Seasons ', ' 3 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 5 Seasons ', ' 3 Seasons ', ' 3 Seasons ', ' 2 Seasons ', ' 1 Seasons ', ' 3 Seasons ', ' 5 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 5 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 4 Seasons ', ' 4 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 3 Seasons ', ' 2 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 2 Seasons ', ' 1 Seasons ', ' 7 Seasons ', ' 2 Seasons ', ' 5 Seasons ', ' 4 Seasons ', ' 1 Seasons ', ' 3 Seasons ', ' 1 Seasons ', ' 8 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 2 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 2 Seasons ', ' 2 Seasons ', ' 3 Seasons ', ' 2 Seasons ', ' 2 Seasons ', ' 3 Seasons ', ' 2 Seasons ', ' 2 Seasons ', ' 6 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 4 Seasons ', ' 8 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 6 Seasons ', ' 11 Seasons ', ' 2 Seasons ', ' 1 Seasons ', ' 4 Seasons ', ' 1 Seasons ', ' 24 Seasons ', ' 5 Seasons ', ' 2 Seasons ', ' 1 Seasons ', ' 6 Seasons ', ' 1 Seasons ', ' 1 Seasons ', ' 5 Seasons ', ' 2 Seasons ', ' 3 Seasons ', ' 2 Seasons ', ' 3 Seasons ', ' 2 Seasons ', ' 11 Seasons ', ' 6 Seasons ', ' 6 Seasons ', ' 4 Seasons ', ' 2 Seasons ', ' 11 Seasons ', ' 9 Seasons ', ' 2 Seasons ', ' 2 Seasons ', ' 4 Seasons ', ' 2 Seasons ', ' 12 Seasons ', ' 9 Seasons ', ' 7 Seasons ', ' 1 Seasons ', ' 9 Seasons ']

# %%
#replacing 'Seasons' with 'S' in duration
tvshow_duration=[s.replace('Seasons','S') for s in tvshow_duration]
print(tvshow_duration)
# Out:
# [' 3 S ', ' 4 S ', ' 1 S ', ' 3 S ', ' 1 S ', ' 8 S ', ' 17 S ', ' 3 S ', ' 3 S ', ' 1 S ', ' 1 S ', ' 1 S ', ' 5 S ', ' 3 S ', ' 3 S ', ' 2 S ', ' 1 S ', ' 3 S ', ' 5 S ', ' 1 S ', ' 1 S ', ' 5 S ', ' 1 S ', ' 1 S ', ' 4 S ', ' 4 S ', ' 1 S ', ' 1 S ', ' 3 S ', ' 2 S ', ' 1 S ', ' 1 S ', ' 2 S ', ' 1 S ', ' 7 S ', ' 2 S ', ' 5 S ', ' 4 S ', ' 1 S ', ' 3 S ', ' 1 S ', ' 8 S ', ' 1 S ', ' 1 S ', ' 2 S ', ' 1 S ', ' 1 S ', ' 1 S ', ' 2 S ', ' 2 S ', ' 3 S ', ' 2 S ', ' 2 S ', ' 3 S ', ' 2 S ', ' 2 S ', ' 6 S ', ' 1 S ', ' 1 S ', ' 1 S ', ' 1 S ', ' 4 S ', ' 8 S ', ' 1 S ', ' 1 S ', ' 6 S ', ' 11 S ', ' 2 S ', ' 1 S ', ' 4 S ', ' 1 S ', ' 24 S ', ' 5 S ', ' 2 S ', ' 1 S ', ' 6 S ', ' 1 S ', ' 1 S ', ' 5 S ', ' 2 S ', ' 3 S ', ' 2 S ', ' 3 S ', ' 2 S ', ' 11 S ', ' 6 S ', ' 6 S ', ' 4 S ', ' 2 S ', ' 11 S ', ' 9 S ', ' 2 S ', ' 2 S ', ' 4 S ', ' 2 S ', ' 12 S ', ' 9 S ', ' 7 S ', ' 1 S ', ' 9 S ']

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Creating a dictionary with keys as column names and values as lists
tvshow_data={'Title':tvshow_title,
            'Release_year':tvshow_release_year,
            'Genre':tvshow_genres,
            'IMDB_Rating':tvshow_imdb_ratings,
            'Age_rating':tvshow_age_rating,
            'Duration':tvshow_duration,
            'Production_country':tvshow_Production_country,
            'Streaming_service':tvshow_streaming_platform,
            'URL':tvshow_urls
              }
# Creating a DataFrame using the dictionary
tvshow_df=pd.DataFrame(tvshow_data)

# %%
#head of Tv show dataframe
tvshow_df.head(10)
# Out:
#                    Title Release_year  \
# 0           jack-reacher         2022
# 1         true-detective         2014
# 2    indian-police-force         2024
# 3               mirzapur         2018
# 4     solo-leveling-2024         2024
# 5        game-of-thrones         2011
# 6              bigg-boss         2006
# 7              panchayat         2020
# 8  the-legend-of-hanuman         2021
# 9            killer-soup         2024
#
#                                                Genre IMDB_Rating Age_rating  \
# 0  Drama, Mystery & Thriller, Action & Adventure,...         8.1          A
# 1                   Drama, Crime, Mystery & Thriller         8.9          U
# 2                          Action & Adventure, Crime         5.7          A
# 3  Crime, Action & Adventure, Drama, Mystery & Th...         8.5         NA
# 4  Fantasy, Animation, Action & Adventure, Scienc...         8.4         NA
# 5  Drama, Action & Adventure, Science-Fiction, Fa...         9.2          U
# 6                          Reality TV, Kids & Family         3.7         NA
# 7                                      Comedy, Drama         8.9         NA
# 8             Animation, Action & Adventure, Fantasy         9.2         NA
# 9                  Comedy, Drama, Mystery & Thriller         6.3         NA
#
#   Duration  Production_country   Streaming_service  \
# 0     3 S        United States  Amazon Prime Video
# 1     4 S        United States          Jio Cinema
# 2     1 S                India  Amazon Prime Video
# 3     3 S                India  Amazon Prime Video
# 4     1 S   South Korea, Japan         Crunchyroll
# 5     8 S        United States          Jio Cinema
# 6    17 S                India                Voot
# 7     3 S                India  Amazon Prime Video
# 8     3 S                India             Hotstar
# 9     1 S                India             Netflix
#
#                                                  URL
# 0  https://www.justwatch.com/in/tv-show/jack-reacher
# 1  https://www.justwatch.com/in/tv-show/true-dete...
# 2  https://www.justwatch.com/in/tv-show/indian-po...
# 3      https://www.justwatch.com/in/tv-show/mirzapur
# 4  https://www.justwatch.com/in/tv-show/solo-leve...
# 5  https://www.justwatch.com/in/tv-show/game-of-t...
# 6     https://www.justwatch.com/in/tv-show/bigg-boss
# 7     https://www.justwatch.com/in/tv-show/panchayat
# 8  https://www.justwatch.com/in/tv-show/the-legen...
# 9   https://www.justwatch.com/in/tv-show/killer-soup

# %%
# Adding a new column 'Type' to the DataFrame with constant value 'Tv Show'
tvshow_df['Type']='Tv Show'

# %%
#head of data
tvshow_df.head()
# Out:
#                  Title Release_year  \
# 0         jack-reacher         2022
# 1       true-detective         2014
# 2  indian-police-force         2024
# 3             mirzapur         2018
# 4   solo-leveling-2024         2024
#
#                                                Genre IMDB_Rating Age_rating  \
# 0  Drama, Mystery & Thriller, Action & Adventure,...         8.1          A
# 1                   Drama, Crime, Mystery & Thriller         8.9          U
# 2                          Action & Adventure, Crime         5.7          A
# 3  Crime, Action & Adventure, Drama, Mystery & Th...         8.5         NA
# 4  Fantasy, Animation, Action & Adventure, Scienc...         8.4         NA
#
#   Duration  Production_country   Streaming_service  \
# 0     3 S        United States  Amazon Prime Video
# 1     4 S        United States          Jio Cinema
# 2     1 S                India  Amazon Prime Video
# 3     3 S                India  Amazon Prime Video
# 4     1 S   South Korea, Japan         Crunchyroll
#
#                                                  URL     Type
# 0  https://www.justwatch.com/in/tv-show/jack-reacher  Tv Show
# 1  https://www.justwatch.com/in/tv-show/true-dete...  Tv Show
# 2  https://www.justwatch.com/in/tv-show/indian-po...  Tv Show
# 3      https://www.justwatch.com/in/tv-show/mirzapur  Tv Show
# 4  https://www.justwatch.com/in/tv-show/solo-leve...  Tv Show

# %%
#shape of data
tvshow_df.shape
# Out:
# (100, 10)

# %%
#tv show data info
tvshow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               100 non-null    object
#  1   Release_year        100 non-null    float64
#  2   Genre               100 non-null    object
#  3   IMDB_Rating         97 non-null     float64
#  4   Age_rating          100 non-null    object
#  5   Duration            100 non-null    object
#  6   Production_country  100 non-null    object
#  7   Streaming_service   100 non-null    object
#  8   URL                 100 non-null    object
#  9   Type                100 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 7.9+ KB

# %%
#converting release year to date format
tvshow_df['Release_year'] = pd.to_datetime(tvshow_df['Release_year'], format='%Y').dt.year

# %%
tvshow_df = tvshow_df.replace(r'^\s*$', np.nan, regex=True)

# %%
# Replace 'NA' with NaN (Not a Number)
tvshow_df['IMDB_Rating'].replace('NA',float('nan'),inplace=True)

# Convert the 'IMDB_Rating' column to float
tvshow_df['Release_year'] = tvshow_df['Release_year'].astype(float)
tvshow_df['IMDB_Rating'] = tvshow_df['IMDB_Rating'].astype(float)

# %% [markdown]
# ##**Concatinate movies_df and tvshow_df**

# %%
# Combining both movie_df and tvshow_df into single DataFrame
final_df=pd.concat([movie_df,tvshow_df],ignore_index=True)

# %%
#head of final DataFrame
final_df.head(5)
# Out:
#                           Title  Release_year  \
# 0                   animal-2022        2023.0
# 1                     12th-fail        2023.0
# 2                        salaar        2023.0
# 3                   sam-bahadur        2023.0
# 4  aquaman-and-the-lost-kingdom        2023.0
#
#                                                Genre  IMDB_Rating Age_rating  \
# 0  Action & Adventure, Drama, Crime, Mystery & Th...          6.4          A
# 1                                              Drama          9.2         NA
# 2  Action & Adventure, Crime, Drama, Mystery & Th...          6.6          A
# 3                     War & Military, Drama, History          7.9         UA
# 4       Action & Adventure, Fantasy, Science-Fiction          5.7         NA
#
#    Duration Production_country Streaming_service  \
# 0  3h 21min              India           Netflix
# 1  2h 26min              India           Hotstar
# 2  2h 55min              India           Netflix
# 3  2h 30min              India              Zee5
# 4   2h 4min      United States          Apple TV
#
#                                                  URL   Type
# 0     https://www.justwatch.com/in/movie/animal-2022  Movie
# 1       https://www.justwatch.com/in/movie/12th-fail  Movie
# 2          https://www.justwatch.com/in/movie/salaar  Movie
# 3     https://www.justwatch.com/in/movie/sam-bahadur  Movie
# 4  https://www.justwatch.com/in/movie/aquaman-and...  Movie

# %%
final_df.shape
# Out:
# (200, 10)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               200 non-null    object
#  1   Release_year        200 non-null    float64
#  2   Genre               200 non-null    object
#  3   IMDB_Rating         195 non-null    float64
#  4   Age_rating          200 non-null    object
#  5   Duration            200 non-null    object
#  6   Production_country  200 non-null    object
#  7   Streaming_service   200 non-null    object
#  8   URL                 200 non-null    object
#  9   Type                200 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 15.8+ KB

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
filter_data=final_df.query("Release_year >=2022 & IMDB_Rating >= 7")

# %%
filter_data.head()
# Out:
#          Title  Release_year  \
# 1    12th-fail        2023.0
# 3  sam-bahadur        2023.0
# 6       nani30        2023.0
# 7  oppenheimer        2023.0
# 8     hanu-man        2024.0
#
#                                                Genre  IMDB_Rating Age_rating  \
# 1                                              Drama          9.2         NA
# 3                     War & Military, Drama, History          7.9         UA
# 6                      Drama, Kids & Family, Romance          8.3          U
# 7                                     Drama, History          8.4         UA
# 8  Fantasy, Action & Adventure, Comedy, Science-F...          8.5         UA
#
#    Duration             Production_country Streaming_service  \
# 1  2h 26min                          India           Hotstar
# 3  2h 30min                          India              Zee5
# 6  2h 35min                          India           Netflix
# 7   3h 1min  United Kingdom, United States          Apple TV
# 8  2h 39min                          India                NA
#
#                                               URL   Type
# 1    https://www.justwatch.com/in/movie/12th-fail  Movie
# 3  https://www.justwatch.com/in/movie/sam-bahadur  Movie
# 6       https://www.justwatch.com/in/movie/nani30  Movie
# 7  https://www.justwatch.com/in/movie/oppenheimer  Movie
# 8     https://www.justwatch.com/in/movie/hanu-man  Movie

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
#determining average ratings for both movie and tv shows
print("Mean IMDb Ratings:")
final_df.groupby('Type').agg({'IMDB_Rating':'mean'})
# Out:
# Mean IMDb Ratings:
#          IMDB_Rating
# Type
# Movie       7.221429
# Tv Show     7.906186

# %%
#Showing Top Genres in Movie using Word Cloud

#import all necessary Labraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Extracting genres and joining them into a single string
all_genres_text = ', '.join(movie_df['Genre'].fillna('').values)

# Creating a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='Black').generate(all_genres_text)

# Displaying the WordCloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Movie Genres')
plt.show()

# %% [markdown]
# ### So we have **Drama,Action Adventure, Mystery Thriller,Comedy,Science Fiction, Crime** as some of the top Genres in Movies

# %%
#Showing Top Genres in TV show using Word Cloud

# Extracting genres and joining them into a single string
all_genres_text = ', '.join(tvshow_df['Genre'].fillna('').values)

# Creating a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='Black').generate(all_genres_text)

# Displaying the WordCloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of TV Show Genres')
plt.show()

# %% [markdown]
# ## In Tv Shows also we can see that **Drame, Action Adventure, Mystery Thriller, Crime Drama, Comedy, Science Fiction** are top

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
#finding Predominant Streaming Service in Movies
movie_df['Streaming_service'].value_counts()
# Out:
# Apple TV              31
# NA                    26
# Amazon Prime Video    15
# Netflix               13
# Hotstar                4
# Zee5                   3
# Apple TV Plus          2
# Lionsgate Play         2
# Sony Liv               2
# Amazon Video           1
# Voot                   1
# Name: Streaming_service, dtype: int64

# %% [markdown]
# **Apple TV** is predominant Streaming service followed by **Amazon Prime Video** and **Netflix** in Movies

# %%
#Let's Visvalize it using word cloud

# Extracting streaming service and joining them into a single string
all_streaming_text = ', '.join(movie_df['Streaming_service'].fillna('').values)

# Creating a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='Black').generate(all_streaming_text)

# Displaying the WordCloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Movie Streaming Service')
plt.show()

# %%
#finding Predominant Streaming Service in Tv shows
tvshow_df['Streaming_service'].value_counts()
# Out:
# Netflix               30
# Amazon Prime Video    17
# Hotstar               13
# Sony Liv               8
# NA                     8
# Jio Cinema             7
# Crunchyroll            6
# Apple TV Plus          3
# Voot                   2
# MX Player              2
# Lionsgate Play         2
# Alt Balaji             1
# Amazon miniTV          1
# Name: Streaming_service, dtype: int64

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format
final_df.to_csv('Final Data.csv',index=False)

# %%
#saving filter data as Filter Data in csv format
filter_data.to_csv('Filtered Data.csv',index=False)

# %% [markdown]
# ##**Summary and Technical document**

# %% [markdown]
# I Extracted data from https://www.justwatch.com website, fetched top rated movies  and tvshows.
# There are 200 recorda and 10 columns in final dataset.100 records and 10 columns in movies dataset and 100 records and 10 columns in rvshows dataset.
# All movies 2022 to till now feched from final dataset in the filter dataset and all movies and tvshows which rating is greater than and equal to 7.
#
#  My last knowledge update in January 2022, I don't have real-time data, including the current top-rated movies on IMDb. IMDb ratings can change over time as more users contribute their reviews and ratings.
#
# However, I can guide you on how to find this information and provide a general template for a summary and technical document of a movie:
#
#
# To find the latest IMDb ratings and information for the top-rated movies, please visit the IMDb website or use their API if available. Keep in mind that IMDb ratings are subject to change as more users contribute their opinions.
